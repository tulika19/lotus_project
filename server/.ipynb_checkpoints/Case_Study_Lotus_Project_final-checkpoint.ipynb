# %%
#import the pandas library

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

# read in the csv file as a pandas dataframe
print('WORKBANK DATASET LOAD AND DROP NA')
df_worldBank = pd.read_csv('world_bank_dataset_1.csv')

# explore the data
df_worldBank.info()

df_worldBank.shape

# checking our dataframe to see if the mappings have worked
df_worldBank.head()

df_worldBank_new=df_worldBank.dropna()
#print(df_worldBank_new)
# read in the csv file as a pandas dataframe
#print('LOTUS DATASET LOAD AND DROP NA')

df_lotus_dataset = pd.read_csv('Data_lotus_dataset.csv')
df_new_lotus= df_lotus_dataset.dropna()
#print(df_new_lotus)

# explore the data
df_new_lotus.info()

df_new_lotus.shape

# checking our dataframe to see if the mappings have worked
df_new_lotus.head()

merged = pd.merge(df_worldBank_new,df_new_lotus, left_on = 'Country Name', right_on = 'Country', how = 'inner')
#print(' FINAL OUTPUT:')
#print(merged.head())
#print(type(merged))

# writing the final dataframe to an excel file

#merged.to_excel('merged_final.xlsx', sheet_name='Data')

# count the unique values in the Country column
#print(merged.Country.value_counts())


merged.to_csv(path_or_buf="/Users/ygovindp/Desktop/lotus_project/Lotus_project_Data_Engineer_CaseStudy_1/file.csv",sep=',')




print('AFTER MERGED CHECK POVERTY PER COUNTRY')



def calculate_poverty_rate(merged):
    poverty_rate = merged.groupby(['Country'])['Poverty'].mean().reset_index()
    print(poverty_rate)
    poverty_rate.plot()
    plt.show()
def calculate_Education_rate(merged) : 
    education_rate = merged.groupby(['Country'])['Education'].mean().reset_index()
    print(education_rate)
    education_rate.plot(kind = 'bar', x = 'Country', y = 'Education')
    plt.show()
    
    

    
calculate_poverty_rate(merged)
calculate_Education_rate(merged)

#with open('result.csv', newline='') as csvfile:
#    spamreader = csv.reader(csvfile, delimiter=' ', quotechar='|')
#    for row in spamreader:
#        print(', '.join(row))
# Out:
# WORKBANK DATASET LOAD AND DROP NA
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2959 entries, 0 to 2958
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country Name   2956 non-null   object
#  1   Country Code   2954 non-null   object
#  2   Series Name    2954 non-null   object
#  3   Series Code    2954 non-null   object
#  4   2000 [YR2000]  2954 non-null   object
#  5   2001 [YR2001]  2954 non-null   object
#  6   2002 [YR2002]  2954 non-null   object
#  7   2003 [YR2003]  2954 non-null   object
#  8   2004 [YR2004]  2954 non-null   object
#  9   2005 [YR2005]  2954 non-null   object
#  10  2006 [YR2006]  2954 non-null   object
#  11  2014 [YR2014]  2954 non-null   object
#  12  2015 [YR2015]  2954 non-null   object
#  13  2016 [YR2016]  2954 non-null   object
#  14  2017 [YR2017]  2954 non-null   object
#  15  2018 [YR2018]  2954 non-null   object
#  16  2019 [YR2019]  2954 non-null   object
#  17  2020 [YR2020]  2954 non-null   object
#  18  2021 [YR2021]  2954 non-null   object
#  19  2022 [YR2022]  2954 non-null   object
# dtypes: object(20)
# memory usage: 462.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3655 entries, 0 to 3654
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          3655 non-null   object
#  1   Year                             3655 non-null   int64
#  2   DPI                              3655 non-null   float64
#  3   Agriculture & Rural Development  3655 non-null   float64
#  4   Aid Effectiveness                3655 non-null   float64
#  5   Climate Change                   3655 non-null   float64
#  6   Economy & Growth                 3655 non-null   float64
#  7   Education                        3655 non-null   float64
#  8   Energy                           3655 non-null   float64
#  9   Environment                      3655 non-null   float64
#  10  External Debt                    3655 non-null   float64
#  11  Financial Sector                 3655 non-null   float64
#  12  Gender                           3655 non-null   float64
#  13  Health                           3655 non-null   float64
#  14  Infrastructure                   3655 non-null   float64
#  15  Poverty                          3655 non-null   float64
#  16  Private Sector                   3655 non-null   float64
#  17  Public Sector                    3655 non-null   float64
#  18  Science & Technology             3655 non-null   float64
#  19  Social Development               3655 non-null   float64
#  20  Social Protection & Labor        3655 non-null   float64
#  21  Trade                            3655 non-null   float64
#  22  Urban Development                3655 non-null   float64
# dtypes: float64(21), int64(1), object(1)
# memory usage: 656.9+ KB
# AFTER MERGED CHECK POVERTY PER COUNTRY
#    Country   Poverty
# 0    India  0.528176
# 1  Vietnam  0.461824
#    Country  Education
# 0    India   0.606824
# 1  Vietnam   0.407882

# %%
print(' FINAL OUTPUT:')
print(merged.head())
print(type(merged))
# Out:
#  FINAL OUTPUT:
#   Country Name Country Code
# 0      Vietnam          VNM  \
# 1      Vietnam          VNM
# 2      Vietnam          VNM
# 3      Vietnam          VNM
# 4      Vietnam          VNM
#
#                                          Series Name     Series Code
# 0  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.ZS  \
# 1  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.ZS
# 2  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.ZS
# 3  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.ZS
# 4  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.ZS
#
#   2000 [YR2000] 2001 [YR2001] 2002 [YR2002] 2003 [YR2003] 2004 [YR2004]
# 0          13.4          16.1          19.1          22.1          25.6  \
# 1          13.4          16.1          19.1          22.1          25.6
# 2          13.4          16.1          19.1          22.1          25.6
# 3          13.4          16.1          19.1          22.1          25.6
# 4          13.4          16.1          19.1          22.1          25.6
#
#   2005 [YR2005]  ... Health Infrastructure Poverty Private Sector
# 0          29.1  ...  0.487          0.676   0.474          0.559  \
# 1          29.1  ...  0.523          0.696   0.501          0.575
# 2          29.1  ...  0.549          0.680   0.507          0.575
# 3          29.1  ...  0.551          0.680   0.481          0.602
# 4          29.1  ...  0.561          0.660   0.480          0.633
#
#   Public Sector Science & Technology Social Development
# 0         0.546                0.714              0.420  \
# 1         0.530                0.684              0.409
# 2         0.508                0.698              0.401
# 3         0.514                0.671              0.410
# 4         0.509                0.640              0.417
#
#   Social Protection & Labor  Trade Urban Development
# 0                     0.391  0.552             0.598
# 1                     0.370  0.480             0.605
# 2                     0.374  0.459             0.612
# 3                     0.409  0.439             0.604
# 4                     0.428  0.440             0.608
#
# [5 rows x 43 columns]
# <class 'pandas.core.frame.DataFrame'>

# %%
print(merged.columns)
print(len(merged.columns))
# Out:
# Index(['Country Name', 'Country Code', 'Series Name', 'Series Code',
#        '2000 [YR2000]', '2001 [YR2001]', '2002 [YR2002]', '2003 [YR2003]',
#        '2004 [YR2004]', '2005 [YR2005]', '2006 [YR2006]', '2014 [YR2014]',
#        '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]',
#        '2019 [YR2019]', '2020 [YR2020]', '2021 [YR2021]', '2022 [YR2022]',
#        'Country', 'Year', 'DPI', 'Agriculture & Rural Development',
#        'Aid Effectiveness', 'Climate Change', 'Economy & Growth', 'Education',
#        'Energy', 'Environment', 'External Debt', 'Financial Sector', 'Gender',
#        'Health', 'Infrastructure', 'Poverty', 'Private Sector',
#        'Public Sector', 'Science & Technology', 'Social Development',
#        'Social Protection & Labor', 'Trade', 'Urban Development'],
#       dtype='object')
# 43

# %%
count = 0
# for i,j in merged.iterrows():
#     print(i,j)
#     if count == 44:
#         break;
#     count = count + 1
    
for row in merged.iterrows():
    print(row)
    count = count + 1
    if count > 45:
        break;
# Out:
# (0, Country Name                                                                 Vietnam
# Country Code                                                                     VNM
# Series Name                        Access to clean fuels and technologies for coo...
# Series Code                                                           EG.CFT.ACCS.ZS
# 2000 [YR2000]                                                                   13.4
# 2001 [YR2001]                                                                   16.1
# 2002 [YR2002]                                                                   19.1
# 2003 [YR2003]                                                                   22.1
# 2004 [YR2004]                                                                   25.6
# 2005 [YR2005]                                                                   29.1
# 2006 [YR2006]                                                                     33
# 2014 [YR2014]                                                                   73.8
# 2015 [YR2015]                                                                   78.7
# 2016 [YR2016]                                                                   83.7
# 2017 [YR2017]                                                                   87.4
# 2018 [YR2018]                                                                   90.7
# 2019 [YR2019]                                                                     93
# 2020 [YR2020]                                                                   94.7
# 2021 [YR2021]                                                                   96.1
# 2022 [YR2022]                                                                     ..
# Country                                                                      Vietnam
# Year                                                                            
# 2022 [YR2022]                                                                     ..
# Country                                                                      Vietnam
# Year                                                                            2010
# DPI                                                                            0.495
# Agriculture & Rural Development                                                0.636
# Aid Effectiveness                                                              0.405
# Climate Change                                                                 0.672
# Economy & Growth                                                               0.639
# Education                                                                      0.387
# Energy                                                                         0.521
# Environment                                                                    0.534
# External Debt                                                                  0.437
# Financial Sector                                                               0.444
# Gender                                                                         0.313
# Health                                                                         0.471
# Infrastructure                                                                 0.554
# Poverty                                                                        0.546
# Private Sector                                                                 0.413
# Public Sector                                                                  0.519
# Science & Technology                                                           0.613
# Social Development                                                             0.384
# Social Protection & Labor                                                      0.383
# Trade                                                                          0.404
# Urban Development                                                              0.648
# Name: 44, dtype: object)
# (45, Country Name                                                                 Vietnam
# Country Code                                                                     VNM
# Series Name                        Access to clean fuels and technologies for coo...
# Series Code                                                        EG.CFT.ACCS.UR.ZS
# 2000 [YR2000]                                                                   38.8
# 2001 [YR2001]                                                                   44.6
# 2002 [YR2002]                                                                   50.3
# 2003 [YR2003]                                                                   55.5
# 2004 [YR2004]                                                                   60.3
# 2005 [YR2005]                                                                   65.4
# 2006 [YR2006]                                                                   69.4
# 2014 [YR2014]                                                                   91.9
# 2015 [YR2015]                                                                   93.6
# 2016 [YR2016]                                                                   94.9
# 2017 [YR2017]                                                                     96
# 2018 [YR2018]                                                                   96.9
# 2019 [YR2019]                                                                   97.6
# 2020 [YR2020]                                                                   98.2
# 2021 [YR2021]                                                                   98.6
# 2022 [YR2022]                                                                     ..
# Country                                                                      Vietnam
# Year                                                                            2011
# DPI                                                                            0.477
# Agriculture & Rural Development                                                 0.65
# Aid Effectiveness                                                              0.405
# Climate Change                                                                 0.635
# Economy & Growth                                                                0.63
# Education                                                                      0.386
# Energy                                                                         0.495
# Environment                                                                    0.552
# External Debt                                                                  0.442
# Financial Sector                                                                0.38
# Gender                                                                         0.293
# Health                                                                         0.497
# Infrastructure                                                                 0.594
# Poverty                                                                        0.458
# Private Sector                                                                 0.459
# Public Sector                                                                  0.501
# Science & Technology                                                           0.612
# Social Development                                                             0.378
# Social Protection & Labor                                                       0.39
# Trade                                                                          0.421
# Urban Development                                                              0.642
# Name: 45, dtype: object)

# %%
import pymongo

#mongodb+srv://Tulika2023:YsHW7I6JTeGMRf3g@cluster0.guzjbni.mongodb.net/?retryWrites=true&w=majority
df_worldBank = pd.read_csv('world_bank_dataset_1.csv')
df_worldBank.head()
# Out:
#   Country Name Country Code
# 0      Vietnam          VNM  \
# 1      Vietnam          VNM
# 2      Vietnam          VNM
# 3      Vietnam          VNM
# 4      Vietnam          VNM
#
#                                          Series Name        Series Code
# 0  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS  \
# 1  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.RU.ZS
# 2  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.UR.ZS
# 3            Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
#
#   2000 [YR2000] 2001 [YR2001] 2002 [YR2002] 2003 [YR2003] 2004 [YR2004]
# 0          13.4          16.1          19.1          22.1          25.6  \
# 1           4.3           5.7           7.4           9.5          11.9
# 2          38.8          44.6          50.3          55.5          60.3
# 3   88.23509979   88.91989899          89.1   90.27086639   90.95104218
# 4   84.72297417   85.52862015   85.57245504    87.1467683   87.97423093
#
#   2005 [YR2005] 2006 [YR2006] 2014 [YR2014] 2015 [YR2015] 2016 [YR2016]
# 0          29.1            33          73.8          78.7          83.7  \
# 1          14.9          18.2          64.8          71.8          77.7
# 2          65.4          69.4          91.9          93.6          94.9
# 3          96.1            96          99.2   99.25421143          99.2
# 4   94.78695251   94.80113157   98.85342753   98.87389759   98.77843946
#
#   2017 [YR2017] 2018 [YR2018] 2019 [YR2019] 2020 [YR2020] 2021 [YR2021]
# 0          87.4          90.7            93          94.7          96.1  \
# 1          83.3          87.8            91          93.4          95.1
# 2            96          96.9          97.6          98.2          98.6
# 3           100           100          99.4          99.8           100
# 4           100           100   99.05320961   99.74040855           100
#
#   2022 [YR2022]
# 0            ..
# 1            ..
# 2            ..
# 3            ..
# 4            ..

# %%
import os
directory = os.getcwd()
print(directory)
# Out:
# /Users/ygovindp/Desktop/lotus_project/Lotus_project_Data_Engineer_CaseStudy_1

# %%
myclient = pymongo.MongoClient("mongodb+srv://Tulika2023:YsHW7I6JTeGMRf3g@cluster0.guzjbni.mongodb.net/?retryWrites=true")
mydb = myclient["lotus"]
mycol = mydb["case_study"] # table

mydict = { "name": "John", "address": "Highway 37" }

x = mycol.insert_one(mydict)

cols = ['Country','Year',
'Education',
'Poverty',
'Health',
'Trade',
'Environment',
'Energy',
'Gender']

# Country
# Year
# Education
# Poverty
# Health
# Trade
# Environment
# Energy
# Gender
print(cols)

# %%
cols = ['Country','Year','Education','Poverty','Health','Trade','Environment','Energy','Gender']
print(cols)
count = 0
for index, row in merged.iterrows():
    databaseRow = {}
    for col in cols:
        databaseRow[col] = row[col]
    # Single row generated
    # now push to DB
    print(databaseRow)
    x = mycol.insert_one(databaseRow)
    
    # Mongo DB Cloud Explorer can show upto 200 documents(rows)
    count = count + 1
    if count > 150:
        break;
    print(x)
# Out:
# ['Country', 'Year', 'Education', 'Poverty', 'Health', 'Trade', 'Environment', 'Energy', 'Gender']
# {'Country': 'Vietnam', 'Year': 2000, 'Education': 0.46, 'Poverty': 0.474, 'Health': 0.487, 'Trade': 0.552, 'Environment': 0.654, 'Energy': 0.424, 'Gender': 0.396}
# <pymongo.results.InsertOneResult object at 0x12f0c17c0>
# {'Country': 'Vietnam', 'Year': 2001, 'Education': 0.442, 'Poverty': 0.501, 'Health': 0.523, 'Trade': 0.48, 'Environment': 0.52, 'Energy': 0.436, 'Gender': 0.392}
# <pymongo.results.InsertOneResult object at 0x12f0c18e0>
# {'Country': 'Vietnam', 'Year': 2002, 'Education': 0.465, 'Poverty': 0.507, 'Health': 0.549, 'Trade': 0.459, 'Environment': 0.521, 'Energy': 0.439, 'Gender': 0.338}
# <pymongo.results.InsertOneResult object at 0x12f0d3eb0>
# {'Country': 'Vietnam', 'Year': 2003, 'Education': 0.451, 'Poverty': 0.481, 'Health': 0.551, 'Trade': 0.439, 'Environment': 0.522, 'Energy': 0.437, 'Gender': 0.334}
# <pymongo.results.InsertOneResult object at 0x126dbd100>
# {'Country': 'Vietnam', 'Year': 2004, 'Education': 0.439, 'Poverty': 0.48, 'Health': 0.561, 'Trade': 0.44, 'Environment': 0.56, 'Energy': 0.443, 'Gender': 0.302}
# <pymongo.results.InsertOneResult object at 0x126b08f10>
# {'Country': 'Vietnam', 'Year': 2005, 'Education': 0.437, 'Poverty': 0.457, 'Health': 0.549, 'Trade': 0.461, 'Environment': 0.563, 'Energy': 0.463, 'Gender': 0.327}
# <pymongo.results.InsertOneResult object at 0x12f0c18e0>
# {'Country': 'Vietnam', 'Year': 2006, 'Education': 0.422, 'Poverty': 0.438, 'Health': 0.536, 'Trade': 0.448, 'Environment': 0.569, 'Energy': 0.459, 'Gender': 0.323}
# <pymongo.results.InsertOneResult object at 0x125134100>
# {'Country': 'Vietnam', 'Year': 2007, 'Education': 0.404, 'Poverty': 0.457, 'Health': 0.546, 'Trade': 0.467, 'Environment': 0.561, 'Energy': 0.46, 'Gender': 0.293}
# <pymongo.results.InsertOneResult object at 0x12f0c18e0>
# {'Country': 'Vietnam', 'Year': 2008, 'Education': 0.383, 'Poverty': 0.447, 'Health': 0.521, 'Trade': 0.433, 'Environment': 0.575, 'Energy': 0.462, 'Gender': 0.313}
# <pymongo.results.InsertOneResult object at 0x12f0c1dc0>
# {'Country': 'Vietnam', 'Year': 2009, 'Education': 0.39, 'Poverty': 0.478, 'Health': 0.498, 'Trade': 0.428, 'Environment': 0.513, 'Energy': 0.486, 'Gender': 0.313}
# <pymongo.results.InsertOneResult object at 0x12f0c1730>
# {'Country': 'Vietnam', 'Year': 2010, 'Education': 0.387, 'Poverty': 0.546, 'Health': 0.471, 'Trade': 0.404, 'Environment': 0.534, 'Energy': 0.521, 'Gender': 0.313}
# <pymongo.results.InsertOneResult object at 0x12f0d3e80>
# {'Country': 'Vietnam', 'Year': 2011, 'Education': 0.386, 'Poverty': 0.458, 'Health': 0.497, 'Trade': 0.421, 'Environment': 0.552, 'Energy': 0.495, 'Gender': 0.293}
# <pymongo.results.InsertOneResult object at 0x12f0d3eb0>
# {'Country': 'Vietnam', 'Year': 2012, 'Education': 0.364, 'Poverty': 0.433, 'Health': 0.492, 'Trade': 0.427, 'Environment': 0.554, 'Energy': 0.485, 'Gender': 0.296}
# <pymongo.results.InsertOneResult object at 0x12f0c1730>
# {'Country': 'Vietnam', 'Year': 2013, 'Education': 0.378, 'Poverty': 0.445, 'Health': 0.496, 'Trade': 0.422, 'Environment': 0.567, 'Energy': 0.477, 'Gender': 0.294}
# <pymongo.results.InsertOneResult object at 0x12f0c1dc0>
# {'Country': 'Vietnam', 'Year': 2014, 'Education': 0.383, 'Poverty': 0.407, 'Health': 0.507, 'Trade': 0.388, 'Environment': 0.515, 'Energy': 0.492, 'Gender': 0.315}
# <pymongo.results.InsertOneResult object at 0x126dc9790>
# {'Country': 'Vietnam', 'Year': 2015, 'Education': 0.372, 'Poverty': 0.429, 'Health': 0.486, 'Trade': 0.432, 'Environment': 0.48, 'Energy': 0.529, 'Gender': 0.331}
# <pymongo.results.InsertOneResult object at 0x1251348b0>
# {'Country': 'Vietnam', 'Year': 2016, 'Education': 0.371, 'Poverty': 0.413, 'Health': 0.491, 'Trade': 0.445, 'Environment': 0.472, 'Energy': 0.526, 'Gender': 0.327}
# <pymongo.results.InsertOneResult object at 0x125134100>
# {'Country': 'Vietnam', 'Year': 2000, 'Education': 0.46, 'Poverty': 0.474, 'Health': 0.487, 'Trade': 0.552, 'Environment': 0.654, 'Energy': 0.424, 'Gender': 0.396}
# <pymongo.results.InsertOneResult object at 0x126b08f10>
# {'Country': 'Vietnam', 'Year': 2001, 'Education': 0.442, 'Poverty': 0.501, 'Health': 0.523, 'Trade': 0.48, 'Environment': 0.52, 'Energy': 0.436, 'Gender': 0.392}
# <pymongo.results.InsertOneResult object at 0x12f0c1dc0>
# {'Country': 'Vietnam', 'Year': 2002, 'Education': 0.465, 'Poverty': 0.507, 'Health': 0.549, 'Trade': 0.459, 'Environment': 0.521, 'Energy': 0.439, 'Gender': 0.338}
# <pymongo.results.InsertOneResult object at 0x12f0c17c0>
# {'Country': 'Vietnam', 'Year': 2003, 'Education': 0.451, 'Poverty': 0.481, 'Health': 0.551, 'Trade': 0.439, 'Environment': 0.522, 'Energy': 0.437, 'Gender': 0.334}
# <pymongo.results.InsertOneResult object at 0x126dc9790>
# {'Country': 'Vietnam', 'Year': 2004, 'Education': 0.439, 'Poverty': 0.48, 'Health': 0.561, 'Trade': 0.44, 'Environment': 0.56, 'Energy': 0.443, 'Gender': 0.302}
# <pymongo.results.InsertOneResult object at 0x126b08f10>
# {'Country': 'Vietnam', 'Year': 2005, 'Education': 0.437, 'Poverty': 0.457, 'Health': 0.549, 'Trade': 0.461, 'Environment': 0.563, 'Energy': 0.463, 'Gender': 0.327}
# <pymongo.results.InsertOneResult object at 0x12f0d3e80>
# {'Country': 'Vietnam', 'Year': 2006, 'Education': 0.422, 'Poverty': 0.438, 'Health': 0.536, 'Trade': 0.448, 'Environment': 0.569, 'Energy': 0.459, 'Gender': 0.323}
# <pymongo.results.InsertOneResult object at 0x126b7a970>
# {'Country': 'Vietnam', 'Year': 2007, 'Education': 0.404, 'Poverty': 0.457, 'Health': 0.546, 'Trade': 0.467, 'Environment': 0.561, 'Energy': 0.46, 'Gender': 0.293}
# <pymongo.results.InsertOneResult object at 0x12f0c18e0>
# {'Country': 'Vietnam', 'Year': 2008, 'Education': 0.383, 'Poverty': 0.447, 'Health': 0.521, 'Trade': 0.433, 'Environment': 0.575, 'Energy': 0.462, 'Gender': 0.313}
# <pymongo.results.InsertOneResult object at 0x126dbd100>
# {'Country': 'Vietnam', 'Year': 2009, 'Education': 0.39, 'Poverty': 0.478, 'Health': 0.498, 'Trade': 0.428, 'Environment': 0.513, 'Energy': 0.486, 'Gender': 0.313}
# <pymongo.results.InsertOneResult object at 0x126dc9850>
# {'Country': 'Vietnam', 'Year': 2010, 'Education': 0.387, 'Poverty': 0.546, 'Health': 0.471, 'Trade': 0.404, 'Environment': 0.534, 'Energy': 0.521, 'Gender': 0.313}
# <pymongo.results.InsertOneResult object at 0x126b08f10>
# {'Country': 'Vietnam', 'Year': 2011, 'Education': 0.386, 'Poverty': 0.458, 'Health': 0.497, 'Trade': 0.421, 'Environment': 0.552, 'Energy': 0.495, 'Gender': 0.293}
# <pymongo.results.InsertOneResult object at 0x1251e3d60>
# {'Country': 'Vietnam', 'Year': 2012, 'Education': 0.364, 'Poverty': 0.433, 'Health': 0.492, 'Trade': 0.427, 'Environment': 0.554, 'Energy': 0.485, 'Gender': 0.296}
# <pymongo.results.InsertOneResult object at 0x126dc9850>
# {'Country': 'Vietnam', 'Year': 2013, 'Education': 0.378, 'Poverty': 0.445, 'Health': 0.496, 'Trade': 0.422, 'Environment': 0.567, 'Energy': 0.477, 'Gender': 0.294}
# <pymongo.results.InsertOneResult object at 0x12f0c1dc0>
# {'Country': 'Vietnam', 'Year': 2014, 'Education': 0.383, 'Poverty': 0.407, 'Health': 0.507, 'Trade': 0.388, 'Environment': 0.515, 'Energy': 0.492, 'Gender': 0.315}
# <pymongo.results.InsertOneResult object at 0x12f0c1730>
# {'Country': 'Vietnam', 'Year': 2015, 'Education': 0.372, 'Poverty': 0.429, 'Health': 0.486, 'Trade': 0.432, 'Environment': 0.48, 'Energy': 0.529, 'Gender': 0.331}
# <pymongo.results.InsertOneResult object at 0x126dbd100>
# {'Country': 'Vietnam', 'Year': 2016, 'Education': 0.371, 'Poverty': 0.413, 'Health': 0.491, 'Trade': 0.445, 'Environment': 0.472, 'Energy': 0.526, 'Gender': 0.327}
# <pymongo.results.InsertOneResult object at 0x12f0d3550>
# {'Country': 'Vietnam', 'Year': 2000, 'Education': 0.46, 'Poverty': 0.474, 'Health': 0.487, 'Trade': 0.552, 'Environment': 0.654, 'Energy': 0.424, 'Gender': 0.396}
# <pymongo.results.InsertOneResult object at 0x12f0c1dc0>
# {'Country': 'Vietnam', 'Year': 2001, 'Education': 0.442, 'Poverty': 0.501, 'Health': 0.523, 'Trade': 0.48, 'Environment': 0.52, 'Energy': 0.436, 'Gender': 0.392}
# <pymongo.results.InsertOneResult object at 0x12f0d3b50>
# {'Country': 'Vietnam', 'Year': 2002, 'Education': 0.465, 'Poverty': 0.507, 'Health': 0.549, 'Trade': 0.459, 'Environment': 0.521, 'Energy': 0.439, 'Gender': 0.338}
# <pymongo.results.InsertOneResult object at 0x12f0d31f0>
# {'Country': 'Vietnam', 'Year': 2003, 'Education': 0.451, 'Poverty': 0.481, 'Health': 0.551, 'Trade': 0.439, 'Environment': 0.522, 'Energy': 0.437, 'Gender': 0.334}
# <pymongo.results.InsertOneResult object at 0x12f0d3eb0>
# {'Country': 'Vietnam', 'Year': 2004, 'Education': 0.439, 'Poverty': 0.48, 'Health': 0.561, 'Trade': 0.44, 'Environment': 0.56, 'Energy': 0.443, 'Gender': 0.302}
# <pymongo.results.InsertOneResult object at 0x12f0d31f0>
# {'Country': 'Vietnam', 'Year': 2005, 'Education': 0.437, 'Poverty': 0.457, 'Health': 0.549, 'Trade': 0.461, 'Environment': 0.563, 'Energy': 0.463, 'Gender': 0.327}
# <pymongo.results.InsertOneResult object at 0x12f0d3e80>
# {'Country': 'Vietnam', 'Year': 2006, 'Education': 0.422, 'Poverty': 0.438, 'Health': 0.536, 'Trade': 0.448, 'Environment': 0.569, 'Energy': 0.459, 'Gender': 0.323}
# <pymongo.results.InsertOneResult object at 0x12f0d3b50>
# {'Country': 'Vietnam', 'Year': 2007, 'Education': 0.404, 'Poverty': 0.457, 'Health': 0.546, 'Trade': 0.467, 'Environment': 0.561, 'Energy': 0.46, 'Gender': 0.293}
# <pymongo.results.InsertOneResult object at 0x12f0d3eb0>
# {'Country': 'Vietnam', 'Year': 2008, 'Education': 0.383, 'Poverty': 0.447, 'Health': 0.521, 'Trade': 0.433, 'Environment': 0.575, 'Energy': 0.462, 'Gender': 0.313}
# <pymongo.results.InsertOneResult object at 0x12f0d3b50>
# {'Country': 'Vietnam', 'Year': 2009, 'Education': 0.39, 'Poverty': 0.478, 'Health': 0.498, 'Trade': 0.428, 'Environment': 0.513, 'Energy': 0.486, 'Gender': 0.313}
# <pymongo.results.InsertOneResult object at 0x12f0d31f0>
# {'Country': 'Vietnam', 'Year': 2010, 'Education': 0.387, 'Poverty': 0.546, 'Health': 0.471, 'Trade': 0.404, 'Environment': 0.534, 'Energy': 0.521, 'Gender': 0.313}
# <pymongo.results.InsertOneResult object at 0x12f0d3b50>
# {'Country': 'Vietnam', 'Year': 2011, 'Education': 0.386, 'Poverty': 0.458, 'Health': 0.497, 'Trade': 0.421, 'Environment': 0.552, 'Energy': 0.495, 'Gender': 0.293}
# <pymongo.results.InsertOneResult object at 0x12f0d3e80>
# {'Country': 'Vietnam', 'Year': 2012, 'Education': 0.364, 'Poverty': 0.433, 'Health': 0.492, 'Trade': 0.427, 'Environment': 0.554, 'Energy': 0.485, 'Gender': 0.296}
# <pymongo.results.InsertOneResult object at 0x12f0d3eb0>
# {'Country': 'Vietnam', 'Year': 2013, 'Education': 0.378, 'Poverty': 0.445, 'Health': 0.496, 'Trade': 0.422, 'Environment': 0.567, 'Energy': 0.477, 'Gender': 0.294}
# <pymongo.results.InsertOneResult object at 0x12f0d31f0>
# {'Country': 'Vietnam', 'Year': 2014, 'Education': 0.383, 'Poverty': 0.407, 'Health': 0.507, 'Trade': 0.388, 'Environment': 0.515, 'Energy': 0.492, 'Gender': 0.315}
# <pymongo.results.InsertOneResult object at 0x12f0d3eb0>
# {'Country': 'Vietnam', 'Year': 2015, 'Education': 0.372, 'Poverty': 0.429, 'Health': 0.486, 'Trade': 0.432, 'Environment': 0.48, 'Energy': 0.529, 'Gender': 0.331}
# <pymongo.results.InsertOneResult object at 0x12f0d3b50>
# {'Country': 'Vietnam', 'Year': 2016, 'Education': 0.371, 'Poverty': 0.413, 'Health': 0.491, 'Trade': 0.445, 'Environment': 0.472, 'Energy': 0.526, 'Gender': 0.327}
# <pymongo.results.InsertOneResult object at 0x12f0d3eb0>
# {'Country': 'Vietnam', 'Year': 2000, 'Education': 0.46, 'Poverty': 0.474, 'Health': 0.487, 'Trade': 0.552, 'Environment': 0.654, 'Energy': 0.424, 'Gender': 0.396}
# <pymongo.results.InsertOneResult object at 0x12f0d3e80>
# {'Country': 'Vietnam', 'Year': 2001, 'Education': 0.442, 'Poverty': 0.501, 'Health': 0.523, 'Trade': 0.48, 'Environment': 0.52, 'Energy': 0.436, 'Gender': 0.392}
# <pymongo.results.InsertOneResult object at 0x12f0d31f0>
# {'Country': 'Vietnam', 'Year': 2002, 'Education': 0.465, 'Poverty': 0.507, 'Health': 0.549, 'Trade': 0.459, 'Environment': 0.521, 'Energy': 0.439, 'Gender': 0.338}
# <pymongo.results.InsertOneResult object at 0x12f0d3b50>
# {'Country': 'Vietnam', 'Year': 2003, 'Education': 0.451, 'Poverty': 0.481, 'Health': 0.551, 'Trade': 0.439, 'Environment': 0.522, 'Energy': 0.437, 'Gender': 0.334}
# <pymongo.results.InsertOneResult object at 0x12f0d31f0>
# {'Country': 'Vietnam', 'Year': 2004, 'Education': 0.439, 'Poverty': 0.48, 'Health': 0.561, 'Trade': 0.44, 'Environment': 0.56, 'Energy': 0.443, 'Gender': 0.302}
# <pymongo.results.InsertOneResult object at 0x12f0d3eb0>
# {'Country': 'Vietnam', 'Year': 2005, 'Education': 0.437, 'Poverty': 0.457, 'Health': 0.549, 'Trade': 0.461, 'Environment': 0.563, 'Energy': 0.463, 'Gender': 0.327}
# <pymongo.results.InsertOneResult object at 0x12f0d31f0>
# {'Country': 'Vietnam', 'Year': 2006, 'Education': 0.422, 'Poverty': 0.438, 'Health': 0.536, 'Trade': 0.448, 'Environment': 0.569, 'Energy': 0.459, 'Gender': 0.323}
# <pymongo.results.InsertOneResult object at 0x12f0d3eb0>
# {'Country': 'Vietnam', 'Year': 2007, 'Education': 0.404, 'Poverty': 0.457, 'Health': 0.546, 'Trade': 0.467, 'Environment': 0.561, 'Energy': 0.46, 'Gender': 0.293}
# <pymongo.results.InsertOneResult object at 0x12f0d3e80>
# {'Country': 'Vietnam', 'Year': 2008, 'Education': 0.383, 'Poverty': 0.447, 'Health': 0.521, 'Trade': 0.433, 'Environment': 0.575, 'Energy': 0.462, 'Gender': 0.313}
# <pymongo.results.InsertOneResult object at 0x12f0d3eb0>
# {'Country': 'Vietnam', 'Year': 2009, 'Education': 0.39, 'Poverty': 0.478, 'Health': 0.498, 'Trade': 0.428, 'Environment': 0.513, 'Energy': 0.486, 'Gender': 0.313}
# <pymongo.results.InsertOneResult object at 0x12f0d3e80>
# {'Country': 'Vietnam', 'Year': 2010, 'Education': 0.387, 'Poverty': 0.546, 'Health': 0.471, 'Trade': 0.404, 'Environment': 0.534, 'Energy': 0.521, 'Gender': 0.313}
# <pymongo.results.InsertOneResult object at 0x12f0d3eb0>
# {'Country': 'Vietnam', 'Year': 2011, 'Education': 0.386, 'Poverty': 0.458, 'Health': 0.497, 'Trade': 0.421, 'Environment': 0.552, 'Energy': 0.495, 'Gender': 0.293}
# <pymongo.results.InsertOneResult object at 0x12f0d3b50>
# {'Country': 'Vietnam', 'Year': 2012, 'Education': 0.364, 'Poverty': 0.433, 'Health': 0.492, 'Trade': 0.427, 'Environment': 0.554, 'Energy': 0.485, 'Gender': 0.296}
# <pymongo.results.InsertOneResult object at 0x12f0d3eb0>
# {'Country': 'Vietnam', 'Year': 2013, 'Education': 0.378, 'Poverty': 0.445, 'Health': 0.496, 'Trade': 0.422, 'Environment': 0.567, 'Energy': 0.477, 'Gender': 0.294}
# <pymongo.results.InsertOneResult object at 0x12f0d31f0>
# {'Country': 'Vietnam', 'Year': 2014, 'Education': 0.383, 'Poverty': 0.407, 'Health': 0.507, 'Trade': 0.388, 'Environment': 0.515, 'Energy': 0.492, 'Gender': 0.315}
# <pymongo.results.InsertOneResult object at 0x12f0d3eb0>
# {'Country': 'Vietnam', 'Year': 2015, 'Education': 0.372, 'Poverty': 0.429, 'Health': 0.486, 'Trade': 0.432, 'Environment': 0.48, 'Energy': 0.529, 'Gender': 0.331}
# <pymongo.results.InsertOneResult object at 0x12f0d31f0>
# {'Country': 'Vietnam', 'Year': 2016, 'Education': 0.371, 'Poverty': 0.413, 'Health': 0.491, 'Trade': 0.445, 'Environment': 0.472, 'Energy': 0.526, 'Gender': 0.327}
# <pymongo.results.InsertOneResult object at 0x12f0d3eb0>
# {'Country': 'Vietnam', 'Year': 2000, 'Education': 0.46, 'Poverty': 0.474, 'Health': 0.487, 'Trade': 0.552, 'Environment': 0.654, 'Energy': 0.424, 'Gender': 0.396}
# <pymongo.results.InsertOneResult object at 0x12f0d3e80>
# {'Country': 'Vietnam', 'Year': 2001, 'Education': 0.442, 'Poverty': 0.501, 'Health': 0.523, 'Trade': 0.48, 'Environment': 0.52, 'Energy': 0.436, 'Gender': 0.392}
# <pymongo.results.InsertOneResult object at 0x12f0d3eb0>
# {'Country': 'Vietnam', 'Year': 2002, 'Education': 0.465, 'Poverty': 0.507, 'Health': 0.549, 'Trade': 0.459, 'Environment': 0.521, 'Energy': 0.439, 'Gender': 0.338}
# <pymongo.results.InsertOneResult object at 0x12f172070>
# {'Country': 'Vietnam', 'Year': 2003, 'Education': 0.451, 'Poverty': 0.481, 'Health': 0.551, 'Trade': 0.439, 'Environment': 0.522, 'Energy': 0.437, 'Gender': 0.334}
# <pymongo.results.InsertOneResult object at 0x12f0d3eb0>
# {'Country': 'Vietnam', 'Year': 2004, 'Education': 0.439, 'Poverty': 0.48, 'Health': 0.561, 'Trade': 0.44, 'Environment': 0.56, 'Energy': 0.443, 'Gender': 0.302}
# <pymongo.results.InsertOneResult object at 0x125134100>
# {'Country': 'Vietnam', 'Year': 2005, 'Education': 0.437, 'Poverty': 0.457, 'Health': 0.549, 'Trade': 0.461, 'Environment': 0.563, 'Energy': 0.463, 'Gender': 0.327}
# <pymongo.results.InsertOneResult object at 0x12f172070>
# {'Country': 'Vietnam', 'Year': 2006, 'Education': 0.422, 'Poverty': 0.438, 'Health': 0.536, 'Trade': 0.448, 'Environment': 0.569, 'Energy': 0.459, 'Gender': 0.323}
# <pymongo.results.InsertOneResult object at 0x126b08f10>
# {'Country': 'Vietnam', 'Year': 2007, 'Education': 0.404, 'Poverty': 0.457, 'Health': 0.546, 'Trade': 0.467, 'Environment': 0.561, 'Energy': 0.46, 'Gender': 0.293}
# <pymongo.results.InsertOneResult object at 0x126dbd100>
# {'Country': 'Vietnam', 'Year': 2008, 'Education': 0.383, 'Poverty': 0.447, 'Health': 0.521, 'Trade': 0.433, 'Environment': 0.575, 'Energy': 0.462, 'Gender': 0.313}
# <pymongo.results.InsertOneResult object at 0x12f0d3190>
# {'Country': 'Vietnam', 'Year': 2009, 'Education': 0.39, 'Poverty': 0.478, 'Health': 0.498, 'Trade': 0.428, 'Environment': 0.513, 'Energy': 0.486, 'Gender': 0.313}
# <pymongo.results.InsertOneResult object at 0x1251206a0>
# {'Country': 'Vietnam', 'Year': 2010, 'Education': 0.387, 'Poverty': 0.546, 'Health': 0.471, 'Trade': 0.404, 'Environment': 0.534, 'Energy': 0.521, 'Gender': 0.313}
# <pymongo.results.InsertOneResult object at 0x12f0d3190>
# {'Country': 'Vietnam', 'Year': 2011, 'Education': 0.386, 'Poverty': 0.458, 'Health': 0.497, 'Trade': 0.421, 'Environment': 0.552, 'Energy': 0.495, 'Gender': 0.293}
# <pymongo.results.InsertOneResult object at 0x125134100>
# {'Country': 'Vietnam', 'Year': 2012, 'Education': 0.364, 'Poverty': 0.433, 'Health': 0.492, 'Trade': 0.427, 'Environment': 0.554, 'Energy': 0.485, 'Gender': 0.296}
# <pymongo.results.InsertOneResult object at 0x12f0d3190>
# {'Country': 'Vietnam', 'Year': 2013, 'Education': 0.378, 'Poverty': 0.445, 'Health': 0.496, 'Trade': 0.422, 'Environment': 0.567, 'Energy': 0.477, 'Gender': 0.294}
# <pymongo.results.InsertOneResult object at 0x126b08f10>
# {'Country': 'Vietnam', 'Year': 2014, 'Education': 0.383, 'Poverty': 0.407, 'Health': 0.507, 'Trade': 0.388, 'Environment': 0.515, 'Energy': 0.492, 'Gender': 0.315}
# <pymongo.results.InsertOneResult object at 0x12f0d3eb0>
# {'Country': 'Vietnam', 'Year': 2015, 'Education': 0.372, 'Poverty': 0.429, 'Health': 0.486, 'Trade': 0.432, 'Environment': 0.48, 'Energy': 0.529, 'Gender': 0.331}
# <pymongo.results.InsertOneResult object at 0x1232a1e20>
# {'Country': 'Vietnam', 'Year': 2016, 'Education': 0.371, 'Poverty': 0.413, 'Health': 0.491, 'Trade': 0.445, 'Environment': 0.472, 'Energy': 0.526, 'Gender': 0.327}
# <pymongo.results.InsertOneResult object at 0x12f0d3eb0>
# {'Country': 'Vietnam', 'Year': 2000, 'Education': 0.46, 'Poverty': 0.474, 'Health': 0.487, 'Trade': 0.552, 'Environment': 0.654, 'Energy': 0.424, 'Gender': 0.396}
# <pymongo.results.InsertOneResult object at 0x12f0c1dc0>
# {'Country': 'Vietnam', 'Year': 2001, 'Education': 0.442, 'Poverty': 0.501, 'Health': 0.523, 'Trade': 0.48, 'Environment': 0.52, 'Energy': 0.436, 'Gender': 0.392}
# <pymongo.results.InsertOneResult object at 0x12f0d3eb0>
# {'Country': 'Vietnam', 'Year': 2002, 'Education': 0.465, 'Poverty': 0.507, 'Health': 0.549, 'Trade': 0.459, 'Environment': 0.521, 'Energy': 0.439, 'Gender': 0.338}
# <pymongo.results.InsertOneResult object at 0x126dbd100>
# {'Country': 'Vietnam', 'Year': 2003, 'Education': 0.451, 'Poverty': 0.481, 'Health': 0.551, 'Trade': 0.439, 'Environment': 0.522, 'Energy': 0.437, 'Gender': 0.334}
# <pymongo.results.InsertOneResult object at 0x12f0d31f0>
# {'Country': 'Vietnam', 'Year': 2004, 'Education': 0.439, 'Poverty': 0.48, 'Health': 0.561, 'Trade': 0.44, 'Environment': 0.56, 'Energy': 0.443, 'Gender': 0.302}
# <pymongo.results.InsertOneResult object at 0x12eed4e50>
# {'Country': 'Vietnam', 'Year': 2005, 'Education': 0.437, 'Poverty': 0.457, 'Health': 0.549, 'Trade': 0.461, 'Environment': 0.563, 'Energy': 0.463, 'Gender': 0.327}
# <pymongo.results.InsertOneResult object at 0x12f0d31f0>
# {'Country': 'Vietnam', 'Year': 2006, 'Education': 0.422, 'Poverty': 0.438, 'Health': 0.536, 'Trade': 0.448, 'Environment': 0.569, 'Energy': 0.459, 'Gender': 0.323}
# <pymongo.results.InsertOneResult object at 0x12f0d3eb0>
# {'Country': 'Vietnam', 'Year': 2007, 'Education': 0.404, 'Poverty': 0.457, 'Health': 0.546, 'Trade': 0.467, 'Environment': 0.561, 'Energy': 0.46, 'Gender': 0.293}
# <pymongo.results.InsertOneResult object at 0x12f0d31f0>
# {'Country': 'Vietnam', 'Year': 2008, 'Education': 0.383, 'Poverty': 0.447, 'Health': 0.521, 'Trade': 0.433, 'Environment': 0.575, 'Energy': 0.462, 'Gender': 0.313}
# <pymongo.results.InsertOneResult object at 0x12f0d3eb0>
# {'Country': 'Vietnam', 'Year': 2009, 'Education': 0.39, 'Poverty': 0.478, 'Health': 0.498, 'Trade': 0.428, 'Environment': 0.513, 'Energy': 0.486, 'Gender': 0.313}
# <pymongo.results.InsertOneResult object at 0x12f0d31f0>
# {'Country': 'Vietnam', 'Year': 2010, 'Education': 0.387, 'Poverty': 0.546, 'Health': 0.471, 'Trade': 0.404, 'Environment': 0.534, 'Energy': 0.521, 'Gender': 0.313}
# <pymongo.results.InsertOneResult object at 0x12f0d3b50>
# {'Country': 'Vietnam', 'Year': 2011, 'Education': 0.386, 'Poverty': 0.458, 'Health': 0.497, 'Trade': 0.421, 'Environment': 0.552, 'Energy': 0.495, 'Gender': 0.293}
# <pymongo.results.InsertOneResult object at 0x12f0d31f0>
# {'Country': 'Vietnam', 'Year': 2012, 'Education': 0.364, 'Poverty': 0.433, 'Health': 0.492, 'Trade': 0.427, 'Environment': 0.554, 'Energy': 0.485, 'Gender': 0.296}
# <pymongo.results.InsertOneResult object at 0x12f0d3b50>
# {'Country': 'Vietnam', 'Year': 2013, 'Education': 0.378, 'Poverty': 0.445, 'Health': 0.496, 'Trade': 0.422, 'Environment': 0.567, 'Energy': 0.477, 'Gender': 0.294}
# <pymongo.results.InsertOneResult object at 0x12f0d31f0>
# {'Country': 'Vietnam', 'Year': 2014, 'Education': 0.383, 'Poverty': 0.407, 'Health': 0.507, 'Trade': 0.388, 'Environment': 0.515, 'Energy': 0.492, 'Gender': 0.315}
# <pymongo.results.InsertOneResult object at 0x12f0d3b50>
# {'Country': 'Vietnam', 'Year': 2015, 'Education': 0.372, 'Poverty': 0.429, 'Health': 0.486, 'Trade': 0.432, 'Environment': 0.48, 'Energy': 0.529, 'Gender': 0.331}
# <pymongo.results.InsertOneResult object at 0x12f0d31f0>
# {'Country': 'Vietnam', 'Year': 2016, 'Education': 0.371, 'Poverty': 0.413, 'Health': 0.491, 'Trade': 0.445, 'Environment': 0.472, 'Energy': 0.526, 'Gender': 0.327}
# <pymongo.results.InsertOneResult object at 0x12f0d3550>
# {'Country': 'Vietnam', 'Year': 2000, 'Education': 0.46, 'Poverty': 0.474, 'Health': 0.487, 'Trade': 0.552, 'Environment': 0.654, 'Energy': 0.424, 'Gender': 0.396}
# <pymongo.results.InsertOneResult object at 0x12f0d31f0>
# {'Country': 'Vietnam', 'Year': 2001, 'Education': 0.442, 'Poverty': 0.501, 'Health': 0.523, 'Trade': 0.48, 'Environment': 0.52, 'Energy': 0.436, 'Gender': 0.392}
# <pymongo.results.InsertOneResult object at 0x12f0d3550>
# {'Country': 'Vietnam', 'Year': 2002, 'Education': 0.465, 'Poverty': 0.507, 'Health': 0.549, 'Trade': 0.459, 'Environment': 0.521, 'Energy': 0.439, 'Gender': 0.338}
# <pymongo.results.InsertOneResult object at 0x12f0d31f0>
# {'Country': 'Vietnam', 'Year': 2003, 'Education': 0.451, 'Poverty': 0.481, 'Health': 0.551, 'Trade': 0.439, 'Environment': 0.522, 'Energy': 0.437, 'Gender': 0.334}
# <pymongo.results.InsertOneResult object at 0x12eed4e50>
# {'Country': 'Vietnam', 'Year': 2004, 'Education': 0.439, 'Poverty': 0.48, 'Health': 0.561, 'Trade': 0.44, 'Environment': 0.56, 'Energy': 0.443, 'Gender': 0.302}
# <pymongo.results.InsertOneResult object at 0x12f0d31f0>
# {'Country': 'Vietnam', 'Year': 2005, 'Education': 0.437, 'Poverty': 0.457, 'Health': 0.549, 'Trade': 0.461, 'Environment': 0.563, 'Energy': 0.463, 'Gender': 0.327}
# <pymongo.results.InsertOneResult object at 0x12f172070>
# {'Country': 'Vietnam', 'Year': 2006, 'Education': 0.422, 'Poverty': 0.438, 'Health': 0.536, 'Trade': 0.448, 'Environment': 0.569, 'Energy': 0.459, 'Gender': 0.323}
# <pymongo.results.InsertOneResult object at 0x1232a1e20>
# {'Country': 'Vietnam', 'Year': 2007, 'Education': 0.404, 'Poverty': 0.457, 'Health': 0.546, 'Trade': 0.467, 'Environment': 0.561, 'Energy': 0.46, 'Gender': 0.293}
# <pymongo.results.InsertOneResult object at 0x1251206a0>
# {'Country': 'Vietnam', 'Year': 2008, 'Education': 0.383, 'Poverty': 0.447, 'Health': 0.521, 'Trade': 0.433, 'Environment': 0.575, 'Energy': 0.462, 'Gender': 0.313}
# <pymongo.results.InsertOneResult object at 0x126dbd100>
# {'Country': 'Vietnam', 'Year': 2009, 'Education': 0.39, 'Poverty': 0.478, 'Health': 0.498, 'Trade': 0.428, 'Environment': 0.513, 'Energy': 0.486, 'Gender': 0.313}
# <pymongo.results.InsertOneResult object at 0x1232a1e20>
# {'Country': 'Vietnam', 'Year': 2010, 'Education': 0.387, 'Poverty': 0.546, 'Health': 0.471, 'Trade': 0.404, 'Environment': 0.534, 'Energy': 0.521, 'Gender': 0.313}
# <pymongo.results.InsertOneResult object at 0x1251206a0>
# {'Country': 'Vietnam', 'Year': 2011, 'Education': 0.386, 'Poverty': 0.458, 'Health': 0.497, 'Trade': 0.421, 'Environment': 0.552, 'Energy': 0.495, 'Gender': 0.293}
# <pymongo.results.InsertOneResult object at 0x125134100>
# {'Country': 'Vietnam', 'Year': 2012, 'Education': 0.364, 'Poverty': 0.433, 'Health': 0.492, 'Trade': 0.427, 'Environment': 0.554, 'Energy': 0.485, 'Gender': 0.296}
# <pymongo.results.InsertOneResult object at 0x12f172070>
# {'Country': 'Vietnam', 'Year': 2013, 'Education': 0.378, 'Poverty': 0.445, 'Health': 0.496, 'Trade': 0.422, 'Environment': 0.567, 'Energy': 0.477, 'Gender': 0.294}
# <pymongo.results.InsertOneResult object at 0x1251206a0>
# {'Country': 'Vietnam', 'Year': 2014, 'Education': 0.383, 'Poverty': 0.407, 'Health': 0.507, 'Trade': 0.388, 'Environment': 0.515, 'Energy': 0.492, 'Gender': 0.315}
# <pymongo.results.InsertOneResult object at 0x125134100>
# {'Country': 'Vietnam', 'Year': 2015, 'Education': 0.372, 'Poverty': 0.429, 'Health': 0.486, 'Trade': 0.432, 'Environment': 0.48, 'Energy': 0.529, 'Gender': 0.331}
# <pymongo.results.InsertOneResult object at 0x12f172070>
# {'Country': 'Vietnam', 'Year': 2016, 'Education': 0.371, 'Poverty': 0.413, 'Health': 0.491, 'Trade': 0.445, 'Environment': 0.472, 'Energy': 0.526, 'Gender': 0.327}
# <pymongo.results.InsertOneResult object at 0x12eed4e50>
# {'Country': 'Vietnam', 'Year': 2000, 'Education': 0.46, 'Poverty': 0.474, 'Health': 0.487, 'Trade': 0.552, 'Environment': 0.654, 'Energy': 0.424, 'Gender': 0.396}
# <pymongo.results.InsertOneResult object at 0x1251206a0>
# {'Country': 'Vietnam', 'Year': 2001, 'Education': 0.442, 'Poverty': 0.501, 'Health': 0.523, 'Trade': 0.48, 'Environment': 0.52, 'Energy': 0.436, 'Gender': 0.392}
# <pymongo.results.InsertOneResult object at 0x12f172070>
# {'Country': 'Vietnam', 'Year': 2002, 'Education': 0.465, 'Poverty': 0.507, 'Health': 0.549, 'Trade': 0.459, 'Environment': 0.521, 'Energy': 0.439, 'Gender': 0.338}
# <pymongo.results.InsertOneResult object at 0x12f0d3280>
# {'Country': 'Vietnam', 'Year': 2003, 'Education': 0.451, 'Poverty': 0.481, 'Health': 0.551, 'Trade': 0.439, 'Environment': 0.522, 'Energy': 0.437, 'Gender': 0.334}
# <pymongo.results.InsertOneResult object at 0x126b7a970>
# {'Country': 'Vietnam', 'Year': 2004, 'Education': 0.439, 'Poverty': 0.48, 'Health': 0.561, 'Trade': 0.44, 'Environment': 0.56, 'Energy': 0.443, 'Gender': 0.302}
# <pymongo.results.InsertOneResult object at 0x12f172070>
# {'Country': 'Vietnam', 'Year': 2005, 'Education': 0.437, 'Poverty': 0.457, 'Health': 0.549, 'Trade': 0.461, 'Environment': 0.563, 'Energy': 0.463, 'Gender': 0.327}
# <pymongo.results.InsertOneResult object at 0x12f0c1730>
# {'Country': 'Vietnam', 'Year': 2006, 'Education': 0.422, 'Poverty': 0.438, 'Health': 0.536, 'Trade': 0.448, 'Environment': 0.569, 'Energy': 0.459, 'Gender': 0.323}
# <pymongo.results.InsertOneResult object at 0x126b7a970>
# {'Country': 'Vietnam', 'Year': 2007, 'Education': 0.404, 'Poverty': 0.457, 'Health': 0.546, 'Trade': 0.467, 'Environment': 0.561, 'Energy': 0.46, 'Gender': 0.293}
# <pymongo.results.InsertOneResult object at 0x12f172070>
# {'Country': 'Vietnam', 'Year': 2008, 'Education': 0.383, 'Poverty': 0.447, 'Health': 0.521, 'Trade': 0.433, 'Environment': 0.575, 'Energy': 0.462, 'Gender': 0.313}
# <pymongo.results.InsertOneResult object at 0x12f0c1730>
# {'Country': 'Vietnam', 'Year': 2009, 'Education': 0.39, 'Poverty': 0.478, 'Health': 0.498, 'Trade': 0.428, 'Environment': 0.513, 'Energy': 0.486, 'Gender': 0.313}
# <pymongo.results.InsertOneResult object at 0x126b7a970>
# {'Country': 'Vietnam', 'Year': 2010, 'Education': 0.387, 'Poverty': 0.546, 'Health': 0.471, 'Trade': 0.404, 'Environment': 0.534, 'Energy': 0.521, 'Gender': 0.313}
# <pymongo.results.InsertOneResult object at 0x12f172070>
# {'Country': 'Vietnam', 'Year': 2011, 'Education': 0.386, 'Poverty': 0.458, 'Health': 0.497, 'Trade': 0.421, 'Environment': 0.552, 'Energy': 0.495, 'Gender': 0.293}
# <pymongo.results.InsertOneResult object at 0x12f0c1730>
# {'Country': 'Vietnam', 'Year': 2012, 'Education': 0.364, 'Poverty': 0.433, 'Health': 0.492, 'Trade': 0.427, 'Environment': 0.554, 'Energy': 0.485, 'Gender': 0.296}
# <pymongo.results.InsertOneResult object at 0x126b7a970>
# {'Country': 'Vietnam', 'Year': 2013, 'Education': 0.378, 'Poverty': 0.445, 'Health': 0.496, 'Trade': 0.422, 'Environment': 0.567, 'Energy': 0.477, 'Gender': 0.294}
# <pymongo.results.InsertOneResult object at 0x12f172070>
# {'Country': 'Vietnam', 'Year': 2014, 'Education': 0.383, 'Poverty': 0.407, 'Health': 0.507, 'Trade': 0.388, 'Environment': 0.515, 'Energy': 0.492, 'Gender': 0.315}
# <pymongo.results.InsertOneResult object at 0x12f0c1730>
# {'Country': 'Vietnam', 'Year': 2015, 'Education': 0.372, 'Poverty': 0.429, 'Health': 0.486, 'Trade': 0.432, 'Environment': 0.48, 'Energy': 0.529, 'Gender': 0.331}
# <pymongo.results.InsertOneResult object at 0x126b7a970>
# {'Country': 'Vietnam', 'Year': 2016, 'Education': 0.371, 'Poverty': 0.413, 'Health': 0.491, 'Trade': 0.445, 'Environment': 0.472, 'Energy': 0.526, 'Gender': 0.327}
# <pymongo.results.InsertOneResult object at 0x12f172070>
# {'Country': 'Vietnam', 'Year': 2000, 'Education': 0.46, 'Poverty': 0.474, 'Health': 0.487, 'Trade': 0.552, 'Environment': 0.654, 'Energy': 0.424, 'Gender': 0.396}
# <pymongo.results.InsertOneResult object at 0x12f0c1730>
# {'Country': 'Vietnam', 'Year': 2001, 'Education': 0.442, 'Poverty': 0.501, 'Health': 0.523, 'Trade': 0.48, 'Environment': 0.52, 'Energy': 0.436, 'Gender': 0.392}
# <pymongo.results.InsertOneResult object at 0x126b7a970>
# {'Country': 'Vietnam', 'Year': 2002, 'Education': 0.465, 'Poverty': 0.507, 'Health': 0.549, 'Trade': 0.459, 'Environment': 0.521, 'Energy': 0.439, 'Gender': 0.338}
# <pymongo.results.InsertOneResult object at 0x12f172070>
# {'Country': 'Vietnam', 'Year': 2003, 'Education': 0.451, 'Poverty': 0.481, 'Health': 0.551, 'Trade': 0.439, 'Environment': 0.522, 'Energy': 0.437, 'Gender': 0.334}
# <pymongo.results.InsertOneResult object at 0x12f0c1730>
# {'Country': 'Vietnam', 'Year': 2004, 'Education': 0.439, 'Poverty': 0.48, 'Health': 0.561, 'Trade': 0.44, 'Environment': 0.56, 'Energy': 0.443, 'Gender': 0.302}
# <pymongo.results.InsertOneResult object at 0x126b7a970>
# {'Country': 'Vietnam', 'Year': 2005, 'Education': 0.437, 'Poverty': 0.457, 'Health': 0.549, 'Trade': 0.461, 'Environment': 0.563, 'Energy': 0.463, 'Gender': 0.327}
# <pymongo.results.InsertOneResult object at 0x12f172070>
# {'Country': 'Vietnam', 'Year': 2006, 'Education': 0.422, 'Poverty': 0.438, 'Health': 0.536, 'Trade': 0.448, 'Environment': 0.569, 'Energy': 0.459, 'Gender': 0.323}
# <pymongo.results.InsertOneResult object at 0x12f0c1730>
# {'Country': 'Vietnam', 'Year': 2007, 'Education': 0.404, 'Poverty': 0.457, 'Health': 0.546, 'Trade': 0.467, 'Environment': 0.561, 'Energy': 0.46, 'Gender': 0.293}
# <pymongo.results.InsertOneResult object at 0x126b7a970>
# {'Country': 'Vietnam', 'Year': 2008, 'Education': 0.383, 'Poverty': 0.447, 'Health': 0.521, 'Trade': 0.433, 'Environment': 0.575, 'Energy': 0.462, 'Gender': 0.313}
# <pymongo.results.InsertOneResult object at 0x12f172070>
# {'Country': 'Vietnam', 'Year': 2009, 'Education': 0.39, 'Poverty': 0.478, 'Health': 0.498, 'Trade': 0.428, 'Environment': 0.513, 'Energy': 0.486, 'Gender': 0.313}
# <pymongo.results.InsertOneResult object at 0x12f0c1730>
# {'Country': 'Vietnam', 'Year': 2010, 'Education': 0.387, 'Poverty': 0.546, 'Health': 0.471, 'Trade': 0.404, 'Environment': 0.534, 'Energy': 0.521, 'Gender': 0.313}
# <pymongo.results.InsertOneResult object at 0x126b7a970>
# {'Country': 'Vietnam', 'Year': 2011, 'Education': 0.386, 'Poverty': 0.458, 'Health': 0.497, 'Trade': 0.421, 'Environment': 0.552, 'Energy': 0.495, 'Gender': 0.293}
# <pymongo.results.InsertOneResult object at 0x12f172070>
# {'Country': 'Vietnam', 'Year': 2012, 'Education': 0.364, 'Poverty': 0.433, 'Health': 0.492, 'Trade': 0.427, 'Environment': 0.554, 'Energy': 0.485, 'Gender': 0.296}
# <pymongo.results.InsertOneResult object at 0x12f0c1730>
# {'Country': 'Vietnam', 'Year': 2013, 'Education': 0.378, 'Poverty': 0.445, 'Health': 0.496, 'Trade': 0.422, 'Environment': 0.567, 'Energy': 0.477, 'Gender': 0.294}
# <pymongo.results.InsertOneResult object at 0x126b7a970>
# {'Country': 'Vietnam', 'Year': 2014, 'Education': 0.383, 'Poverty': 0.407, 'Health': 0.507, 'Trade': 0.388, 'Environment': 0.515, 'Energy': 0.492, 'Gender': 0.315}
# <pymongo.results.InsertOneResult object at 0x12f172070>
# {'Country': 'Vietnam', 'Year': 2015, 'Education': 0.372, 'Poverty': 0.429, 'Health': 0.486, 'Trade': 0.432, 'Environment': 0.48, 'Energy': 0.529, 'Gender': 0.331}
# <pymongo.results.InsertOneResult object at 0x12f0c1730>
# {'Country': 'Vietnam', 'Year': 2016, 'Education': 0.371, 'Poverty': 0.413, 'Health': 0.491, 'Trade': 0.445, 'Environment': 0.472, 'Energy': 0.526, 'Gender': 0.327}
# <pymongo.results.InsertOneResult object at 0x126dc97f0>
# {'Country': 'Vietnam', 'Year': 2000, 'Education': 0.46, 'Poverty': 0.474, 'Health': 0.487, 'Trade': 0.552, 'Environment': 0.654, 'Energy': 0.424, 'Gender': 0.396}
# <pymongo.results.InsertOneResult object at 0x126b7a970>
# {'Country': 'Vietnam', 'Year': 2001, 'Education': 0.442, 'Poverty': 0.501, 'Health': 0.523, 'Trade': 0.48, 'Environment': 0.52, 'Energy': 0.436, 'Gender': 0.392}
# <pymongo.results.InsertOneResult object at 0x12f0c1730>
# {'Country': 'Vietnam', 'Year': 2002, 'Education': 0.465, 'Poverty': 0.507, 'Health': 0.549, 'Trade': 0.459, 'Environment': 0.521, 'Energy': 0.439, 'Gender': 0.338}
# <pymongo.results.InsertOneResult object at 0x1251348b0>
# {'Country': 'Vietnam', 'Year': 2003, 'Education': 0.451, 'Poverty': 0.481, 'Health': 0.551, 'Trade': 0.439, 'Environment': 0.522, 'Energy': 0.437, 'Gender': 0.334}
# <pymongo.results.InsertOneResult object at 0x125134100>
# {'Country': 'Vietnam', 'Year': 2004, 'Education': 0.439, 'Poverty': 0.48, 'Health': 0.561, 'Trade': 0.44, 'Environment': 0.56, 'Energy': 0.443, 'Gender': 0.302}
# <pymongo.results.InsertOneResult object at 0x12f0d31f0>
# {'Country': 'Vietnam', 'Year': 2005, 'Education': 0.437, 'Poverty': 0.457, 'Health': 0.549, 'Trade': 0.461, 'Environment': 0.563, 'Energy': 0.463, 'Gender': 0.327}
# <pymongo.results.InsertOneResult object at 0x12f0d3b50>
# {'Country': 'Vietnam', 'Year': 2006, 'Education': 0.422, 'Poverty': 0.438, 'Health': 0.536, 'Trade': 0.448, 'Environment': 0.569, 'Energy': 0.459, 'Gender': 0.323}
# <pymongo.results.InsertOneResult object at 0x12f0d3e80>
# {'Country': 'Vietnam', 'Year': 2007, 'Education': 0.404, 'Poverty': 0.457, 'Health': 0.546, 'Trade': 0.467, 'Environment': 0.561, 'Energy': 0.46, 'Gender': 0.293}
# <pymongo.results.InsertOneResult object at 0x12f0d31f0>
# {'Country': 'Vietnam', 'Year': 2008, 'Education': 0.383, 'Poverty': 0.447, 'Health': 0.521, 'Trade': 0.433, 'Environment': 0.575, 'Energy': 0.462, 'Gender': 0.313}
# <pymongo.results.InsertOneResult object at 0x12f0d3280>
# {'Country': 'Vietnam', 'Year': 2009, 'Education': 0.39, 'Poverty': 0.478, 'Health': 0.498, 'Trade': 0.428, 'Environment': 0.513, 'Energy': 0.486, 'Gender': 0.313}
# <pymongo.results.InsertOneResult object at 0x12f0d3e80>
# {'Country': 'Vietnam', 'Year': 2010, 'Education': 0.387, 'Poverty': 0.546, 'Health': 0.471, 'Trade': 0.404, 'Environment': 0.534, 'Energy': 0.521, 'Gender': 0.313}
# <pymongo.results.InsertOneResult object at 0x12f0d3550>
# {'Country': 'Vietnam', 'Year': 2011, 'Education': 0.386, 'Poverty': 0.458, 'Health': 0.497, 'Trade': 0.421, 'Environment': 0.552, 'Energy': 0.495, 'Gender': 0.293}
# <pymongo.results.InsertOneResult object at 0x125134100>
# {'Country': 'Vietnam', 'Year': 2012, 'Education': 0.364, 'Poverty': 0.433, 'Health': 0.492, 'Trade': 0.427, 'Environment': 0.554, 'Energy': 0.485, 'Gender': 0.296}
# <pymongo.results.InsertOneResult object at 0x126dc97f0>
# {'Country': 'Vietnam', 'Year': 2013, 'Education': 0.378, 'Poverty': 0.445, 'Health': 0.496, 'Trade': 0.422, 'Environment': 0.567, 'Energy': 0.477, 'Gender': 0.294}
# <pymongo.results.InsertOneResult object at 0x126dc9fd0>
# {'Country': 'Vietnam', 'Year': 2014, 'Education': 0.383, 'Poverty': 0.407, 'Health': 0.507, 'Trade': 0.388, 'Environment': 0.515, 'Energy': 0.492, 'Gender': 0.315}
# <pymongo.results.InsertOneResult object at 0x126dc9850>
# {'Country': 'Vietnam', 'Year': 2015, 'Education': 0.372, 'Poverty': 0.429, 'Health': 0.486, 'Trade': 0.432, 'Environment': 0.48, 'Energy': 0.529, 'Gender': 0.331}
# <pymongo.results.InsertOneResult object at 0x126dc97c0>
# {'Country': 'Vietnam', 'Year': 2016, 'Education': 0.371, 'Poverty': 0.413, 'Health': 0.491, 'Trade': 0.445, 'Environment': 0.472, 'Energy': 0.526, 'Gender': 0.327}
# <pymongo.results.InsertOneResult object at 0x126dc9790>
# {'Country': 'Vietnam', 'Year': 2000, 'Education': 0.46, 'Poverty': 0.474, 'Health': 0.487, 'Trade': 0.552, 'Environment': 0.654, 'Energy': 0.424, 'Gender': 0.396}
# <pymongo.results.InsertOneResult object at 0x126dc97f0>
# {'Country': 'Vietnam', 'Year': 2001, 'Education': 0.442, 'Poverty': 0.501, 'Health': 0.523, 'Trade': 0.48, 'Environment': 0.52, 'Energy': 0.436, 'Gender': 0.392}
# <pymongo.results.InsertOneResult object at 0x126dc9fd0>
# {'Country': 'Vietnam', 'Year': 2002, 'Education': 0.465, 'Poverty': 0.507, 'Health': 0.549, 'Trade': 0.459, 'Environment': 0.521, 'Energy': 0.439, 'Gender': 0.338}
# <pymongo.results.InsertOneResult object at 0x12f0d3190>
# {'Country': 'Vietnam', 'Year': 2003, 'Education': 0.451, 'Poverty': 0.481, 'Health': 0.551, 'Trade': 0.439, 'Environment': 0.522, 'Energy': 0.437, 'Gender': 0.334}
# <pymongo.results.InsertOneResult object at 0x12f0c18e0>
# {'Country': 'Vietnam', 'Year': 2004, 'Education': 0.439, 'Poverty': 0.48, 'Health': 0.561, 'Trade': 0.44, 'Environment': 0.56, 'Energy': 0.443, 'Gender': 0.302}
# <pymongo.results.InsertOneResult object at 0x126dc9fd0>
# {'Country': 'Vietnam', 'Year': 2005, 'Education': 0.437, 'Poverty': 0.457, 'Health': 0.549, 'Trade': 0.461, 'Environment': 0.563, 'Energy': 0.463, 'Gender': 0.327}
# <pymongo.results.InsertOneResult object at 0x126dc97f0>
# {'Country': 'Vietnam', 'Year': 2006, 'Education': 0.422, 'Poverty': 0.438, 'Health': 0.536, 'Trade': 0.448, 'Environment': 0.569, 'Energy': 0.459, 'Gender': 0.323}
# <pymongo.results.InsertOneResult object at 0x126dc97c0>
# {'Country': 'Vietnam', 'Year': 2007, 'Education': 0.404, 'Poverty': 0.457, 'Health': 0.546, 'Trade': 0.467, 'Environment': 0.561, 'Energy': 0.46, 'Gender': 0.293}
# <pymongo.results.InsertOneResult object at 0x126dc9850>
# {'Country': 'Vietnam', 'Year': 2008, 'Education': 0.383, 'Poverty': 0.447, 'Health': 0.521, 'Trade': 0.433, 'Environment': 0.575, 'Energy': 0.462, 'Gender': 0.313}
# <pymongo.results.InsertOneResult object at 0x12f0d3e80>
# {'Country': 'Vietnam', 'Year': 2009, 'Education': 0.39, 'Poverty': 0.478, 'Health': 0.498, 'Trade': 0.428, 'Environment': 0.513, 'Energy': 0.486, 'Gender': 0.313}
# <pymongo.results.InsertOneResult object at 0x12f0c1730>
# {'Country': 'Vietnam', 'Year': 2010, 'Education': 0.387, 'Poverty': 0.546, 'Health': 0.471, 'Trade': 0.404, 'Environment': 0.534, 'Energy': 0.521, 'Gender': 0.313}
# <pymongo.results.InsertOneResult object at 0x12f0c17c0>
# {'Country': 'Vietnam', 'Year': 2011, 'Education': 0.386, 'Poverty': 0.458, 'Health': 0.497, 'Trade': 0.421, 'Environment': 0.552, 'Energy': 0.495, 'Gender': 0.293}
# <pymongo.results.InsertOneResult object at 0x12f0d3550>
# {'Country': 'Vietnam', 'Year': 2012, 'Education': 0.364, 'Poverty': 0.433, 'Health': 0.492, 'Trade': 0.427, 'Environment': 0.554, 'Energy': 0.485, 'Gender': 0.296}
# <pymongo.results.InsertOneResult object at 0x12f0d3b50>
# {'Country': 'Vietnam', 'Year': 2013, 'Education': 0.378, 'Poverty': 0.445, 'Health': 0.496, 'Trade': 0.422, 'Environment': 0.567, 'Energy': 0.477, 'Gender': 0.294}
# <pymongo.results.InsertOneResult object at 0x126dc97c0>
# {'Country': 'Vietnam', 'Year': 2014, 'Education': 0.383, 'Poverty': 0.407, 'Health': 0.507, 'Trade': 0.388, 'Environment': 0.515, 'Energy': 0.492, 'Gender': 0.315}
# <pymongo.results.InsertOneResult object at 0x126dc9790>
# {'Country': 'Vietnam', 'Year': 2015, 'Education': 0.372, 'Poverty': 0.429, 'Health': 0.486, 'Trade': 0.432, 'Environment': 0.48, 'Energy': 0.529, 'Gender': 0.331}
# <pymongo.results.InsertOneResult object at 0x12eed4e50>
# {'Country': 'Vietnam', 'Year': 2016, 'Education': 0.371, 'Poverty': 0.413, 'Health': 0.491, 'Trade': 0.445, 'Environment': 0.472, 'Energy': 0.526, 'Gender': 0.327}
# <pymongo.results.InsertOneResult object at 0x126dc97f0>
# {'Country': 'Vietnam', 'Year': 2000, 'Education': 0.46, 'Poverty': 0.474, 'Health': 0.487, 'Trade': 0.552, 'Environment': 0.654, 'Energy': 0.424, 'Gender': 0.396}
# <pymongo.results.InsertOneResult object at 0x126dc9850>
# {'Country': 'Vietnam', 'Year': 2001, 'Education': 0.442, 'Poverty': 0.501, 'Health': 0.523, 'Trade': 0.48, 'Environment': 0.52, 'Energy': 0.436, 'Gender': 0.392}
# <pymongo.results.InsertOneResult object at 0x12f0d3190>
# {'Country': 'Vietnam', 'Year': 2002, 'Education': 0.465, 'Poverty': 0.507, 'Health': 0.549, 'Trade': 0.459, 'Environment': 0.521, 'Energy': 0.439, 'Gender': 0.338}
# <pymongo.results.InsertOneResult object at 0x12f0d3550>
# {'Country': 'Vietnam', 'Year': 2003, 'Education': 0.451, 'Poverty': 0.481, 'Health': 0.551, 'Trade': 0.439, 'Environment': 0.522, 'Energy': 0.437, 'Gender': 0.334}
# <pymongo.results.InsertOneResult object at 0x12f0d3e80>
# {'Country': 'Vietnam', 'Year': 2004, 'Education': 0.439, 'Poverty': 0.48, 'Health': 0.561, 'Trade': 0.44, 'Environment': 0.56, 'Energy': 0.443, 'Gender': 0.302}
# <pymongo.results.InsertOneResult object at 0x12f0d3b50>
# {'Country': 'Vietnam', 'Year': 2005, 'Education': 0.437, 'Poverty': 0.457, 'Health': 0.549, 'Trade': 0.461, 'Environment': 0.563, 'Energy': 0.463, 'Gender': 0.327}
# <pymongo.results.InsertOneResult object at 0x12f0d31f0>
# {'Country': 'Vietnam', 'Year': 2006, 'Education': 0.422, 'Poverty': 0.438, 'Health': 0.536, 'Trade': 0.448, 'Environment': 0.569, 'Energy': 0.459, 'Gender': 0.323}
# <pymongo.results.InsertOneResult object at 0x12f0d3550>
# {'Country': 'Vietnam', 'Year': 2007, 'Education': 0.404, 'Poverty': 0.457, 'Health': 0.546, 'Trade': 0.467, 'Environment': 0.561, 'Energy': 0.46, 'Gender': 0.293}
# <pymongo.results.InsertOneResult object at 0x12f0d3190>
# {'Country': 'Vietnam', 'Year': 2008, 'Education': 0.383, 'Poverty': 0.447, 'Health': 0.521, 'Trade': 0.433, 'Environment': 0.575, 'Energy': 0.462, 'Gender': 0.313}
# <pymongo.results.InsertOneResult object at 0x12f0d3280>
# {'Country': 'Vietnam', 'Year': 2009, 'Education': 0.39, 'Poverty': 0.478, 'Health': 0.498, 'Trade': 0.428, 'Environment': 0.513, 'Energy': 0.486, 'Gender': 0.313}
# <pymongo.results.InsertOneResult object at 0x12f0d3b50>
# {'Country': 'Vietnam', 'Year': 2010, 'Education': 0.387, 'Poverty': 0.546, 'Health': 0.471, 'Trade': 0.404, 'Environment': 0.534, 'Energy': 0.521, 'Gender': 0.313}
# <pymongo.results.InsertOneResult object at 0x12f0d3e80>
# {'Country': 'Vietnam', 'Year': 2011, 'Education': 0.386, 'Poverty': 0.458, 'Health': 0.497, 'Trade': 0.421, 'Environment': 0.552, 'Energy': 0.495, 'Gender': 0.293}
# <pymongo.results.InsertOneResult object at 0x12f0d3190>
# {'Country': 'Vietnam', 'Year': 2012, 'Education': 0.364, 'Poverty': 0.433, 'Health': 0.492, 'Trade': 0.427, 'Environment': 0.554, 'Energy': 0.485, 'Gender': 0.296}
# <pymongo.results.InsertOneResult object at 0x12f0d3550>
# {'Country': 'Vietnam', 'Year': 2013, 'Education': 0.378, 'Poverty': 0.445, 'Health': 0.496, 'Trade': 0.422, 'Environment': 0.567, 'Energy': 0.477, 'Gender': 0.294}
# <pymongo.results.InsertOneResult object at 0x12f0d31f0>
# {'Country': 'Vietnam', 'Year': 2014, 'Education': 0.383, 'Poverty': 0.407, 'Health': 0.507, 'Trade': 0.388, 'Environment': 0.515, 'Energy': 0.492, 'Gender': 0.315}
# <pymongo.results.InsertOneResult object at 0x12f0d3b50>
# {'Country': 'Vietnam', 'Year': 2015, 'Education': 0.372, 'Poverty': 0.429, 'Health': 0.486, 'Trade': 0.432, 'Environment': 0.48, 'Energy': 0.529, 'Gender': 0.331}
# <pymongo.results.InsertOneResult object at 0x12f0d3190>
# {'Country': 'Vietnam', 'Year': 2016, 'Education': 0.371, 'Poverty': 0.413, 'Health': 0.491, 'Trade': 0.445, 'Environment': 0.472, 'Energy': 0.526, 'Gender': 0.327}
# <pymongo.results.InsertOneResult object at 0x12f0d3280>
# {'Country': 'Vietnam', 'Year': 2000, 'Education': 0.46, 'Poverty': 0.474, 'Health': 0.487, 'Trade': 0.552, 'Environment': 0.654, 'Energy': 0.424, 'Gender': 0.396}
# <pymongo.results.InsertOneResult object at 0x12f0d31f0>
# {'Country': 'Vietnam', 'Year': 2001, 'Education': 0.442, 'Poverty': 0.501, 'Health': 0.523, 'Trade': 0.48, 'Environment': 0.52, 'Energy': 0.436, 'Gender': 0.392}
# <pymongo.results.InsertOneResult object at 0x12f0d3e80>
# {'Country': 'Vietnam', 'Year': 2002, 'Education': 0.465, 'Poverty': 0.507, 'Health': 0.549, 'Trade': 0.459, 'Environment': 0.521, 'Energy': 0.439, 'Gender': 0.338}
# <pymongo.results.InsertOneResult object at 0x126dc9850>
# {'Country': 'Vietnam', 'Year': 2003, 'Education': 0.451, 'Poverty': 0.481, 'Health': 0.551, 'Trade': 0.439, 'Environment': 0.522, 'Energy': 0.437, 'Gender': 0.334}
# <pymongo.results.InsertOneResult object at 0x126dc9fd0>
# {'Country': 'Vietnam', 'Year': 2004, 'Education': 0.439, 'Poverty': 0.48, 'Health': 0.561, 'Trade': 0.44, 'Environment': 0.56, 'Energy': 0.443, 'Gender': 0.302}
# <pymongo.results.InsertOneResult object at 0x12f0c18e0>
# {'Country': 'Vietnam', 'Year': 2005, 'Education': 0.437, 'Poverty': 0.457, 'Health': 0.549, 'Trade': 0.461, 'Environment': 0.563, 'Energy': 0.463, 'Gender': 0.327}
# <pymongo.results.InsertOneResult object at 0x126dc97f0>
# {'Country': 'Vietnam', 'Year': 2006, 'Education': 0.422, 'Poverty': 0.438, 'Health': 0.536, 'Trade': 0.448, 'Environment': 0.569, 'Energy': 0.459, 'Gender': 0.323}
# <pymongo.results.InsertOneResult object at 0x12f0d3280>
# {'Country': 'Vietnam', 'Year': 2007, 'Education': 0.404, 'Poverty': 0.457, 'Health': 0.546, 'Trade': 0.467, 'Environment': 0.561, 'Energy': 0.46, 'Gender': 0.293}
# <pymongo.results.InsertOneResult object at 0x12f0d3190>
# {'Country': 'Vietnam', 'Year': 2008, 'Education': 0.383, 'Poverty': 0.447, 'Health': 0.521, 'Trade': 0.433, 'Environment': 0.575, 'Energy': 0.462, 'Gender': 0.313}
# <pymongo.results.InsertOneResult object at 0x12f0d3e80>
# {'Country': 'Vietnam', 'Year': 2009, 'Education': 0.39, 'Poverty': 0.478, 'Health': 0.498, 'Trade': 0.428, 'Environment': 0.513, 'Energy': 0.486, 'Gender': 0.313}
# <pymongo.results.InsertOneResult object at 0x12f0d3a00>
# {'Country': 'Vietnam', 'Year': 2010, 'Education': 0.387, 'Poverty': 0.546, 'Health': 0.471, 'Trade': 0.404, 'Environment': 0.534, 'Energy': 0.521, 'Gender': 0.313}
# <pymongo.results.InsertOneResult object at 0x12f0d31f0>
# {'Country': 'Vietnam', 'Year': 2011, 'Education': 0.386, 'Poverty': 0.458, 'Health': 0.497, 'Trade': 0.421, 'Environment': 0.552, 'Energy': 0.495, 'Gender': 0.293}
# <pymongo.results.InsertOneResult object at 0x12f0d3550>
# {'Country': 'Vietnam', 'Year': 2012, 'Education': 0.364, 'Poverty': 0.433, 'Health': 0.492, 'Trade': 0.427, 'Environment': 0.554, 'Energy': 0.485, 'Gender': 0.296}
# <pymongo.results.InsertOneResult object at 0x12f0d3190>
# {'Country': 'Vietnam', 'Year': 2013, 'Education': 0.378, 'Poverty': 0.445, 'Health': 0.496, 'Trade': 0.422, 'Environment': 0.567, 'Energy': 0.477, 'Gender': 0.294}
# <pymongo.results.InsertOneResult object at 0x12f0d3b50>
# ...
# <pymongo.results.InsertOneResult object at 0x126dc9850>
# {'Country': 'Vietnam', 'Year': 2010, 'Education': 0.387, 'Poverty': 0.546, 'Health': 0.471, 'Trade': 0.404, 'Environment': 0.534, 'Energy': 0.521, 'Gender': 0.313}
# <pymongo.results.InsertOneResult object at 0x126dc97c0>
# {'Country': 'Vietnam', 'Year': 2011, 'Education': 0.386, 'Poverty': 0.458, 'Health': 0.497, 'Trade': 0.421, 'Environment': 0.552, 'Energy': 0.495, 'Gender': 0.293}
# <pymongo.results.InsertOneResult object at 0x126dc9850>
# {'Country': 'Vietnam', 'Year': 2012, 'Education': 0.364, 'Poverty': 0.433, 'Health': 0.492, 'Trade': 0.427, 'Environment': 0.554, 'Energy': 0.485, 'Gender': 0.296}
# <pymongo.results.InsertOneResult object at 0x126dc97f0>
# {'Country': 'Vietnam', 'Year': 2013, 'Education': 0.378, 'Poverty': 0.445, 'Health': 0.496, 'Trade': 0.422, 'Environment': 0.567, 'Energy': 0.477, 'Gender': 0.294}
# <pymongo.results.InsertOneResult object at 0x126dc9850>
# {'Country': 'Vietnam', 'Year': 2014, 'Education': 0.383, 'Poverty': 0.407, 'Health': 0.507, 'Trade': 0.388, 'Environment': 0.515, 'Energy': 0.492, 'Gender': 0.315}
# <pymongo.results.InsertOneResult object at 0x126dc97c0>
# {'Country': 'Vietnam', 'Year': 2015, 'Education': 0.372, 'Poverty': 0.429, 'Health': 0.486, 'Trade': 0.432, 'Environment': 0.48, 'Energy': 0.529, 'Gender': 0.331}
# <pymongo.results.InsertOneResult object at 0x126dbd100>
# {'Country': 'Vietnam', 'Year': 2016, 'Education': 0.371, 'Poverty': 0.413, 'Health': 0.491, 'Trade': 0.445, 'Environment': 0.472, 'Energy': 0.526, 'Gender': 0.327}
# <pymongo.results.InsertOneResult object at 0x12f0d3280>
# {'Country': 'Vietnam', 'Year': 2000, 'Education': 0.46, 'Poverty': 0.474, 'Health': 0.487, 'Trade': 0.552, 'Environment': 0.654, 'Energy': 0.424, 'Gender': 0.396}
# <pymongo.results.InsertOneResult object at 0x126dc9790>
# {'Country': 'Vietnam', 'Year': 2001, 'Education': 0.442, 'Poverty': 0.501, 'Health': 0.523, 'Trade': 0.48, 'Environment': 0.52, 'Energy': 0.436, 'Gender': 0.392}
# <pymongo.results.InsertOneResult object at 0x126dc97f0>
# {'Country': 'Vietnam', 'Year': 2002, 'Education': 0.465, 'Poverty': 0.507, 'Health': 0.549, 'Trade': 0.459, 'Environment': 0.521, 'Energy': 0.439, 'Gender': 0.338}
# <pymongo.results.InsertOneResult object at 0x12f172070>
# {'Country': 'Vietnam', 'Year': 2003, 'Education': 0.451, 'Poverty': 0.481, 'Health': 0.551, 'Trade': 0.439, 'Environment': 0.522, 'Energy': 0.437, 'Gender': 0.334}
# <pymongo.results.InsertOneResult object at 0x126dc9fd0>
# {'Country': 'Vietnam', 'Year': 2004, 'Education': 0.439, 'Poverty': 0.48, 'Health': 0.561, 'Trade': 0.44, 'Environment': 0.56, 'Energy': 0.443, 'Gender': 0.302}
# <pymongo.results.InsertOneResult object at 0x126dbd100>
# {'Country': 'Vietnam', 'Year': 2005, 'Education': 0.437, 'Poverty': 0.457, 'Health': 0.549, 'Trade': 0.461, 'Environment': 0.563, 'Energy': 0.463, 'Gender': 0.327}
# <pymongo.results.InsertOneResult object at 0x126dc97f0>
# {'Country': 'Vietnam', 'Year': 2006, 'Education': 0.422, 'Poverty': 0.438, 'Health': 0.536, 'Trade': 0.448, 'Environment': 0.569, 'Energy': 0.459, 'Gender': 0.323}
# <pymongo.results.InsertOneResult object at 0x12f0c18e0>
# {'Country': 'Vietnam', 'Year': 2007, 'Education': 0.404, 'Poverty': 0.457, 'Health': 0.546, 'Trade': 0.467, 'Environment': 0.561, 'Energy': 0.46, 'Gender': 0.293}
# <pymongo.results.InsertOneResult object at 0x126dc9fd0>
# {'Country': 'Vietnam', 'Year': 2008, 'Education': 0.383, 'Poverty': 0.447, 'Health': 0.521, 'Trade': 0.433, 'Environment': 0.575, 'Energy': 0.462, 'Gender': 0.313}
# <pymongo.results.InsertOneResult object at 0x126dc97f0>
# {'Country': 'Vietnam', 'Year': 2009, 'Education': 0.39, 'Poverty': 0.478, 'Health': 0.498, 'Trade': 0.428, 'Environment': 0.513, 'Energy': 0.486, 'Gender': 0.313}
# <pymongo.results.InsertOneResult object at 0x126dc9fd0>
# {'Country': 'Vietnam', 'Year': 2010, 'Education': 0.387, 'Poverty': 0.546, 'Health': 0.471, 'Trade': 0.404, 'Environment': 0.534, 'Energy': 0.521, 'Gender': 0.313}
# <pymongo.results.InsertOneResult object at 0x126dbd100>
# {'Country': 'Vietnam', 'Year': 2011, 'Education': 0.386, 'Poverty': 0.458, 'Health': 0.497, 'Trade': 0.421, 'Environment': 0.552, 'Energy': 0.495, 'Gender': 0.293}
# <pymongo.results.InsertOneResult object at 0x12f0d3280>
# {'Country': 'Vietnam', 'Year': 2012, 'Education': 0.364, 'Poverty': 0.433, 'Health': 0.492, 'Trade': 0.427, 'Environment': 0.554, 'Energy': 0.485, 'Gender': 0.296}
# <pymongo.results.InsertOneResult object at 0x126dc97f0>
# {'Country': 'Vietnam', 'Year': 2013, 'Education': 0.378, 'Poverty': 0.445, 'Health': 0.496, 'Trade': 0.422, 'Environment': 0.567, 'Energy': 0.477, 'Gender': 0.294}
# <pymongo.results.InsertOneResult object at 0x12f0d3b50>
# {'Country': 'Vietnam', 'Year': 2014, 'Education': 0.383, 'Poverty': 0.407, 'Health': 0.507, 'Trade': 0.388, 'Environment': 0.515, 'Energy': 0.492, 'Gender': 0.315}
# <pymongo.results.InsertOneResult object at 0x126dc97c0>
# {'Country': 'Vietnam', 'Year': 2015, 'Education': 0.372, 'Poverty': 0.429, 'Health': 0.486, 'Trade': 0.432, 'Environment': 0.48, 'Energy': 0.529, 'Gender': 0.331}
# <pymongo.results.InsertOneResult object at 0x126dc9850>
# {'Country': 'Vietnam', 'Year': 2016, 'Education': 0.371, 'Poverty': 0.413, 'Health': 0.491, 'Trade': 0.445, 'Environment': 0.472, 'Energy': 0.526, 'Gender': 0.327}
# <pymongo.results.InsertOneResult object at 0x126dc97c0>
# {'Country': 'Vietnam', 'Year': 2000, 'Education': 0.46, 'Poverty': 0.474, 'Health': 0.487, 'Trade': 0.552, 'Environment': 0.654, 'Energy': 0.424, 'Gender': 0.396}
# <pymongo.results.InsertOneResult object at 0x12f0d31f0>
# {'Country': 'Vietnam', 'Year': 2001, 'Education': 0.442, 'Poverty': 0.501, 'Health': 0.523, 'Trade': 0.48, 'Environment': 0.52, 'Energy': 0.436, 'Gender': 0.392}
# <pymongo.results.InsertOneResult object at 0x125134100>
# {'Country': 'Vietnam', 'Year': 2002, 'Education': 0.465, 'Poverty': 0.507, 'Health': 0.549, 'Trade': 0.459, 'Environment': 0.521, 'Energy': 0.439, 'Gender': 0.338}
# <pymongo.results.InsertOneResult object at 0x1251348b0>
# {'Country': 'Vietnam', 'Year': 2003, 'Education': 0.451, 'Poverty': 0.481, 'Health': 0.551, 'Trade': 0.439, 'Environment': 0.522, 'Energy': 0.437, 'Gender': 0.334}
# <pymongo.results.InsertOneResult object at 0x12f0d3190>
# {'Country': 'Vietnam', 'Year': 2004, 'Education': 0.439, 'Poverty': 0.48, 'Health': 0.561, 'Trade': 0.44, 'Environment': 0.56, 'Energy': 0.443, 'Gender': 0.302}
# <pymongo.results.InsertOneResult object at 0x12f0d31f0>
# {'Country': 'Vietnam', 'Year': 2005, 'Education': 0.437, 'Poverty': 0.457, 'Health': 0.549, 'Trade': 0.461, 'Environment': 0.563, 'Energy': 0.463, 'Gender': 0.327}
# <pymongo.results.InsertOneResult object at 0x12f172070>
# {'Country': 'Vietnam', 'Year': 2006, 'Education': 0.422, 'Poverty': 0.438, 'Health': 0.536, 'Trade': 0.448, 'Environment': 0.569, 'Energy': 0.459, 'Gender': 0.323}
# <pymongo.results.InsertOneResult object at 0x12f0d31f0>
# {'Country': 'Vietnam', 'Year': 2007, 'Education': 0.404, 'Poverty': 0.457, 'Health': 0.546, 'Trade': 0.467, 'Environment': 0.561, 'Energy': 0.46, 'Gender': 0.293}
# <pymongo.results.InsertOneResult object at 0x1251348b0>
# {'Country': 'Vietnam', 'Year': 2008, 'Education': 0.383, 'Poverty': 0.447, 'Health': 0.521, 'Trade': 0.433, 'Environment': 0.575, 'Energy': 0.462, 'Gender': 0.313}
# <pymongo.results.InsertOneResult object at 0x12f0d31f0>
# {'Country': 'Vietnam', 'Year': 2009, 'Education': 0.39, 'Poverty': 0.478, 'Health': 0.498, 'Trade': 0.428, 'Environment': 0.513, 'Energy': 0.486, 'Gender': 0.313}
# <pymongo.results.InsertOneResult object at 0x12f0d3190>
# {'Country': 'Vietnam', 'Year': 2010, 'Education': 0.387, 'Poverty': 0.546, 'Health': 0.471, 'Trade': 0.404, 'Environment': 0.534, 'Energy': 0.521, 'Gender': 0.313}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [33], line 11
#       8 # Single row generated
#       9 # now push to DB
#      10 print(databaseRow)
# ---> 11 x = mycol.insert_one(databaseRow)
#      12 print(x)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pymongo/collection.py:671, in Collection.insert_one(self, document, bypass_document_validation, session, comment)
#     667     document["_id"] = ObjectId()  # type: ignore[index]
#     669 write_concern = self._write_concern_for(session)
#     670 return InsertOneResult(
# --> 671     self._insert_one(
#     672         document,
#     673         ordered=True,
#     674         write_concern=write_concern,
#     675         op_id=None,
#     676         bypass_doc_val=bypass_document_validation,
#     677         session=session,
#     678         comment=comment,
#     679     ),
#     680     write_concern.acknowledged,
#     681 )
#
# File ~/Library/Python/3.9/lib/python/site-packages/pymongo/collection.py:611, in Collection._insert_one(self, doc, ordered, write_concern, op_id, bypass_doc_val, session, comment)
#     599     result = conn.command(
#     600         self.__database.name,
#     601         command,
#    (...)
#     606         retryable_write=retryable_write,
#     607     )
#     609     _check_write_command_response(result)
# --> 611 self.__database.client._retryable_write(acknowledged, _insert_command, session)
#     613 if not isinstance(doc, RawBSONDocument):
#     614     return doc.get("_id")
#
# File ~/Library/Python/3.9/lib/python/site-packages/pymongo/mongo_client.py:1568, in MongoClient._retryable_write(self, retryable, func, session)
#    1566 """Internal retryable write helper."""
#    1567 with self._tmp_session(session) as s:
# -> 1568     return self._retry_with_session(retryable, func, s, None)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pymongo/mongo_client.py:1413, in MongoClient._retry_with_session(self, retryable, func, session, bulk)
#    1403 """Execute an operation with at most one consecutive retries
#    1404
#    1405 Returns func()'s return value on success. On error retries the same
#    (...)
#    1408 Re-raises any exception thrown by func().
#    1409 """
#    1410 retryable = bool(
#    1411     retryable and self.options.retry_writes and session and not session.in_transaction
#    1412 )
# -> 1413 return self._retry_internal(retryable, func, session, bulk)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pymongo/_csot.py:108, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     106         with _TimeoutContext(timeout):
#     107             return func(self, *args, **kwargs)
# --> 108 return func(self, *args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pymongo/mongo_client.py:1460, in MongoClient._retry_internal(self, retryable, func, session, bulk)
#    1458                 raise last_error
#    1459             retryable = False
# -> 1460         return func(session, conn, retryable)
#    1461 except ServerSelectionTimeoutError:
#    1462     if is_retrying():
#    1463         # The application may think the write was never attempted
#    1464         # if we raise ServerSelectionTimeoutError on the retry
#    1465         # attempt. Raise the original exception instead.
#
# File ~/Library/Python/3.9/lib/python/site-packages/pymongo/collection.py:599, in Collection._insert_one.<locals>._insert_command(session, conn, retryable_write)
#     596 if bypass_doc_val:
#     597     command["bypassDocumentValidation"] = True
# --> 599 result = conn.command(
#     600     self.__database.name,
#     601     command,
#     602     write_concern=write_concern,
#     603     codec_options=self.__write_response_codec_options,
#     604     session=session,
#     605     client=self.__database.client,
#     606     retryable_write=retryable_write,
#     607 )
#     609 _check_write_command_response(result)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pymongo/helpers.py:315, in _handle_reauth.<locals>.inner(*args, **kwargs)
#     312 from pymongo.pool import Connection
#     314 try:
# --> 315     return func(*args, **kwargs)
#     316 except OperationFailure as exc:
#     317     if no_reauth:
#
# File ~/Library/Python/3.9/lib/python/site-packages/pymongo/pool.py:960, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     958 # Catch socket.error, KeyboardInterrupt, etc. and close ourselves.
#     959 except BaseException as error:
# --> 960     self._raise_connection_failure(error)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pymongo/pool.py:932, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     930     self._raise_if_not_writable(unacknowledged)
#     931 try:
# --> 932     return command(
#     933         self,
#     934         dbname,
#     935         spec,
#     936         self.is_mongos,
#     937         read_preference,
#     938         codec_options,
#     939         session,
#     940         client,
#     941         check,
#     942         allowable_errors,
#     943         self.address,
#     944         listeners,
#     945         self.max_bson_size,
#     946         read_concern,
#     947         parse_write_concern_error=parse_write_concern_error,
#     948         collation=collation,
#     949         compression_ctx=self.compression_context,
#     950         use_op_msg=self.op_msg_enabled,
#     951         unacknowledged=unacknowledged,
#     952         user_fields=user_fields,
#     953         exhaust_allowed=exhaust_allowed,
#     954         write_concern=write_concern,
#     955     )
#     956 except (OperationFailure, NotPrimaryError):
#     957     raise
#
# File ~/Library/Python/3.9/lib/python/site-packages/pymongo/network.py:181, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     179     response_doc: _DocumentOut = {"ok": 1}
#     180 else:
# --> 181     reply = receive_message(conn, request_id)
#     182     conn.more_to_come = reply.more_to_come
#     183     unpacked_docs = reply.unpack_response(
#     184         codec_options=codec_options, user_fields=user_fields
#     185     )
#
# File ~/Library/Python/3.9/lib/python/site-packages/pymongo/network.py:247, in receive_message(conn, request_id, max_message_size)
#     245         deadline = None
#     246 # Ignore the response's request id.
# --> 247 length, _, response_to, op_code = _UNPACK_HEADER(_receive_data_on_socket(conn, 16, deadline))
#     248 # No request_id for exhaust cursor "getMore".
#     249 if request_id is not None:
#
# File ~/Library/Python/3.9/lib/python/site-packages/pymongo/network.py:328, in _receive_data_on_socket(conn, length, deadline)
#     326     if _csot.get_timeout() and deadline is not None:
#     327         conn.set_conn_timeout(max(deadline - time.monotonic(), 0))
# --> 328     chunk_length = conn.conn.recv_into(mv[bytes_read:])
#     329 except BLOCKING_IO_ERRORS:
#     330     raise socket.timeout("timed out")
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
print(type(merged.iterrows()))
# Out:
# <class 'generator'>

# %%
merged.to_dict()["Country"]
# Out:
# {0: 'Vietnam',
#  1: 'Vietnam',
#  2: 'Vietnam',
#  3: 'Vietnam',
#  4: 'Vietnam',
#  5: 'Vietnam',
#  6: 'Vietnam',
#  7: 'Vietnam',
#  8: 'Vietnam',
#  9: 'Vietnam',
#  10: 'Vietnam',
#  11: 'Vietnam',
#  12: 'Vietnam',
#  13: 'Vietnam',
#  14: 'Vietnam',
#  15: 'Vietnam',
#  16: 'Vietnam',
#  17: 'Vietnam',
#  18: 'Vietnam',
#  19: 'Vietnam',
#  20: 'Vietnam',
#  21: 'Vietnam',
#  22: 'Vietnam',
#  23: 'Vietnam',
#  24: 'Vietnam',
#  25: 'Vietnam',
#  26: 'Vietnam',
#  27: 'Vietnam',
#  28: 'Vietnam',
#  29: 'Vietnam',
#  30: 'Vietnam',
#  31: 'Vietnam',
#  32: 'Vietnam',
#  33: 'Vietnam',
#  34: 'Vietnam',
#  35: 'Vietnam',
#  36: 'Vietnam',
#  37: 'Vietnam',
#  38: 'Vietnam',
#  39: 'Vietnam',
#  40: 'Vietnam',
#  41: 'Vietnam',
#  42: 'Vietnam',
#  43: 'Vietnam',
#  44: 'Vietnam',
#  45: 'Vietnam',
#  46: 'Vietnam',
#  47: 'Vietnam',
#  48: 'Vietnam',
#  49: 'Vietnam',
#  50: 'Vietnam',
#  51: 'Vietnam',
#  52: 'Vietnam',
#  53: 'Vietnam',
#  54: 'Vietnam',
#  55: 'Vietnam',
#  56: 'Vietnam',
#  57: 'Vietnam',
#  58: 'Vietnam',
#  59: 'Vietnam',
#  60: 'Vietnam',
#  61: 'Vietnam',
#  62: 'Vietnam',
#  63: 'Vietnam',
#  64: 'Vietnam',
#  65: 'Vietnam',
#  66: 'Vietnam',
#  67: 'Vietnam',
#  68: 'Vietnam',
#  69: 'Vietnam',
#  70: 'Vietnam',
#  71: 'Vietnam',
#  72: 'Vietnam',
#  73: 'Vietnam',
#  74: 'Vietnam',
#  75: 'Vietnam',
#  76: 'Vietnam',
#  77: 'Vietnam',
#  78: 'Vietnam',
#  79: 'Vietnam',
#  80: 'Vietnam',
#  81: 'Vietnam',
#  82: 'Vietnam',
#  83: 'Vietnam',
#  84: 'Vietnam',
#  85: 'Vietnam',
#  86: 'Vietnam',
#  87: 'Vietnam',
#  88: 'Vietnam',
#  89: 'Vietnam',
#  90: 'Vietnam',
#  91: 'Vietnam',
#  92: 'Vietnam',
#  93: 'Vietnam',
#  94: 'Vietnam',
#  95: 'Vietnam',
#  96: 'Vietnam',
#  97: 'Vietnam',
#  98: 'Vietnam',
#  99: 'Vietnam',
#  100: 'Vietnam',
#  101: 'Vietnam',
#  102: 'Vietnam',
#  103: 'Vietnam',
#  104: 'Vietnam',
#  105: 'Vietnam',
#  106: 'Vietnam',
#  107: 'Vietnam',
#  108: 'Vietnam',
#  109: 'Vietnam',
#  110: 'Vietnam',
#  111: 'Vietnam',
#  112: 'Vietnam',
#  113: 'Vietnam',
#  114: 'Vietnam',
#  115: 'Vietnam',
#  116: 'Vietnam',
#  117: 'Vietnam',
#  118: 'Vietnam',
#  119: 'Vietnam',
#  120: 'Vietnam',
#  121: 'Vietnam',
#  122: 'Vietnam',
#  123: 'Vietnam',
#  124: 'Vietnam',
#  125: 'Vietnam',
#  126: 'Vietnam',
#  127: 'Vietnam',
#  128: 'Vietnam',
#  129: 'Vietnam',
#  130: 'Vietnam',
#  131: 'Vietnam',
#  132: 'Vietnam',
#  133: 'Vietnam',
#  134: 'Vietnam',
#  135: 'Vietnam',
#  136: 'Vietnam',
#  137: 'Vietnam',
#  138: 'Vietnam',
#  139: 'Vietnam',
#  140: 'Vietnam',
#  141: 'Vietnam',
#  142: 'Vietnam',
#  143: 'Vietnam',
#  144: 'Vietnam',
#  145: 'Vietnam',
#  146: 'Vietnam',
#  147: 'Vietnam',
#  148: 'Vietnam',
#  149: 'Vietnam',
#  150: 'Vietnam',
#  151: 'Vietnam',
#  152: 'Vietnam',
#  153: 'Vietnam',
#  154: 'Vietnam',
#  155: 'Vietnam',
#  156: 'Vietnam',
#  157: 'Vietnam',
#  158: 'Vietnam',
#  159: 'Vietnam',
#  160: 'Vietnam',
#  161: 'Vietnam',
#  162: 'Vietnam',
#  163: 'Vietnam',
#  164: 'Vietnam',
#  165: 'Vietnam',
#  166: 'Vietnam',
#  167: 'Vietnam',
#  168: 'Vietnam',
#  169: 'Vietnam',
#  170: 'Vietnam',
#  171: 'Vietnam',
#  172: 'Vietnam',
#  173: 'Vietnam',
#  174: 'Vietnam',
#  175: 'Vietnam',
#  176: 'Vietnam',
#  177: 'Vietnam',
#  178: 'Vietnam',
#  179: 'Vietnam',
#  180: 'Vietnam',
#  181: 'Vietnam',
#  182: 'Vietnam',
#  183: 'Vietnam',
#  184: 'Vietnam',
#  185: 'Vietnam',
#  186: 'Vietnam',
#  187: 'Vietnam',
#  188: 'Vietnam',
#  189: 'Vietnam',
#  190: 'Vietnam',
#  191: 'Vietnam',
#  192: 'Vietnam',
#  193: 'Vietnam',
#  194: 'Vietnam',
#  195: 'Vietnam',
#  196: 'Vietnam',
#  197: 'Vietnam',
#  198: 'Vietnam',
#  199: 'Vietnam',
#  200: 'Vietnam',
#  201: 'Vietnam',
#  202: 'Vietnam',
#  203: 'Vietnam',
#  204: 'Vietnam',
#  205: 'Vietnam',
#  206: 'Vietnam',
#  207: 'Vietnam',
#  208: 'Vietnam',
#  209: 'Vietnam',
#  210: 'Vietnam',
#  211: 'Vietnam',
#  212: 'Vietnam',
#  213: 'Vietnam',
#  214: 'Vietnam',
#  215: 'Vietnam',
#  216: 'Vietnam',
#  217: 'Vietnam',
#  218: 'Vietnam',
#  219: 'Vietnam',
#  220: 'Vietnam',
#  221: 'Vietnam',
#  222: 'Vietnam',
#  223: 'Vietnam',
#  224: 'Vietnam',
#  225: 'Vietnam',
#  226: 'Vietnam',
#  227: 'Vietnam',
#  228: 'Vietnam',
#  229: 'Vietnam',
#  230: 'Vietnam',
#  231: 'Vietnam',
#  232: 'Vietnam',
#  233: 'Vietnam',
#  234: 'Vietnam',
#  235: 'Vietnam',
#  236: 'Vietnam',
#  237: 'Vietnam',
#  238: 'Vietnam',
#  239: 'Vietnam',
#  240: 'Vietnam',
#  241: 'Vietnam',
#  242: 'Vietnam',
#  243: 'Vietnam',
#  244: 'Vietnam',
#  245: 'Vietnam',
#  246: 'Vietnam',
#  247: 'Vietnam',
#  248: 'Vietnam',
#  249: 'Vietnam',
#  250: 'Vietnam',
#  251: 'Vietnam',
#  252: 'Vietnam',
#  253: 'Vietnam',
#  254: 'Vietnam',
#  255: 'Vietnam',
#  256: 'Vietnam',
#  257: 'Vietnam',
#  258: 'Vietnam',
#  259: 'Vietnam',
#  260: 'Vietnam',
#  261: 'Vietnam',
#  262: 'Vietnam',
#  263: 'Vietnam',
#  264: 'Vietnam',
#  265: 'Vietnam',
#  266: 'Vietnam',
#  267: 'Vietnam',
#  268: 'Vietnam',
#  269: 'Vietnam',
#  270: 'Vietnam',
#  271: 'Vietnam',
#  272: 'Vietnam',
#  273: 'Vietnam',
#  274: 'Vietnam',
#  275: 'Vietnam',
#  276: 'Vietnam',
#  277: 'Vietnam',
#  278: 'Vietnam',
#  279: 'Vietnam',
#  280: 'Vietnam',
#  281: 'Vietnam',
#  282: 'Vietnam',
#  283: 'Vietnam',
#  284: 'Vietnam',
#  285: 'Vietnam',
#  286: 'Vietnam',
#  287: 'Vietnam',
#  288: 'Vietnam',
#  289: 'Vietnam',
#  290: 'Vietnam',
#  291: 'Vietnam',
#  292: 'Vietnam',
#  293: 'Vietnam',
#  294: 'Vietnam',
#  295: 'Vietnam',
#  296: 'Vietnam',
#  297: 'Vietnam',
#  298: 'Vietnam',
#  299: 'Vietnam',
#  300: 'Vietnam',
#  301: 'Vietnam',
#  302: 'Vietnam',
#  303: 'Vietnam',
#  304: 'Vietnam',
#  305: 'Vietnam',
#  306: 'Vietnam',
#  307: 'Vietnam',
#  308: 'Vietnam',
#  309: 'Vietnam',
#  310: 'Vietnam',
#  311: 'Vietnam',
#  312: 'Vietnam',
#  313: 'Vietnam',
#  314: 'Vietnam',
#  315: 'Vietnam',
#  316: 'Vietnam',
#  317: 'Vietnam',
#  318: 'Vietnam',
#  319: 'Vietnam',
#  320: 'Vietnam',
#  321: 'Vietnam',
#  322: 'Vietnam',
#  323: 'Vietnam',
#  324: 'Vietnam',
#  325: 'Vietnam',
#  326: 'Vietnam',
#  327: 'Vietnam',
#  328: 'Vietnam',
#  329: 'Vietnam',
#  330: 'Vietnam',
#  331: 'Vietnam',
#  332: 'Vietnam',
#  333: 'Vietnam',
#  334: 'Vietnam',
#  335: 'Vietnam',
#  336: 'Vietnam',
#  337: 'Vietnam',
#  338: 'Vietnam',
#  339: 'Vietnam',
#  340: 'Vietnam',
#  341: 'Vietnam',
#  342: 'Vietnam',
#  343: 'Vietnam',
#  344: 'Vietnam',
#  345: 'Vietnam',
#  346: 'Vietnam',
#  347: 'Vietnam',
#  348: 'Vietnam',
#  349: 'Vietnam',
#  350: 'Vietnam',
#  351: 'Vietnam',
#  352: 'Vietnam',
#  353: 'Vietnam',
#  354: 'Vietnam',
#  355: 'Vietnam',
#  356: 'Vietnam',
#  357: 'Vietnam',
#  358: 'Vietnam',
#  359: 'Vietnam',
#  360: 'Vietnam',
#  361: 'Vietnam',
#  362: 'Vietnam',
#  363: 'Vietnam',
#  364: 'Vietnam',
#  365: 'Vietnam',
#  366: 'Vietnam',
#  367: 'Vietnam',
#  368: 'Vietnam',
#  369: 'Vietnam',
#  370: 'Vietnam',
#  371: 'Vietnam',
#  372: 'Vietnam',
#  373: 'Vietnam',
#  374: 'Vietnam',
#  375: 'Vietnam',
#  376: 'Vietnam',
#  377: 'Vietnam',
#  378: 'Vietnam',
#  379: 'Vietnam',
#  380: 'Vietnam',
#  381: 'Vietnam',
#  382: 'Vietnam',
#  383: 'Vietnam',
#  384: 'Vietnam',
#  385: 'Vietnam',
#  386: 'Vietnam',
#  387: 'Vietnam',
#  388: 'Vietnam',
#  389: 'Vietnam',
#  390: 'Vietnam',
#  391: 'Vietnam',
#  392: 'Vietnam',
#  393: 'Vietnam',
#  394: 'Vietnam',
#  395: 'Vietnam',
#  396: 'Vietnam',
#  397: 'Vietnam',
#  398: 'Vietnam',
#  399: 'Vietnam',
#  400: 'Vietnam',
#  401: 'Vietnam',
#  402: 'Vietnam',
#  403: 'Vietnam',
#  404: 'Vietnam',
#  405: 'Vietnam',
#  406: 'Vietnam',
#  407: 'Vietnam',
#  408: 'Vietnam',
#  409: 'Vietnam',
#  410: 'Vietnam',
#  411: 'Vietnam',
#  412: 'Vietnam',
#  413: 'Vietnam',
#  414: 'Vietnam',
#  415: 'Vietnam',
#  416: 'Vietnam',
#  417: 'Vietnam',
#  418: 'Vietnam',
#  419: 'Vietnam',
#  420: 'Vietnam',
#  421: 'Vietnam',
#  422: 'Vietnam',
#  423: 'Vietnam',
#  424: 'Vietnam',
#  425: 'Vietnam',
#  426: 'Vietnam',
#  427: 'Vietnam',
#  428: 'Vietnam',
#  429: 'Vietnam',
#  430: 'Vietnam',
#  431: 'Vietnam',
#  432: 'Vietnam',
#  433: 'Vietnam',
#  434: 'Vietnam',
#  435: 'Vietnam',
#  436: 'Vietnam',
#  437: 'Vietnam',
#  438: 'Vietnam',
#  439: 'Vietnam',
#  440: 'Vietnam',
#  441: 'Vietnam',
#  442: 'Vietnam',
#  443: 'Vietnam',
#  444: 'Vietnam',
#  445: 'Vietnam',
#  446: 'Vietnam',
#  447: 'Vietnam',
#  448: 'Vietnam',
#  449: 'Vietnam',
#  450: 'Vietnam',
#  451: 'Vietnam',
#  452: 'Vietnam',
#  453: 'Vietnam',
#  454: 'Vietnam',
#  455: 'Vietnam',
#  456: 'Vietnam',
#  457: 'Vietnam',
#  458: 'Vietnam',
#  459: 'Vietnam',
#  460: 'Vietnam',
#  461: 'Vietnam',
#  462: 'Vietnam',
#  463: 'Vietnam',
#  464: 'Vietnam',
#  465: 'Vietnam',
#  466: 'Vietnam',
#  467: 'Vietnam',
#  468: 'Vietnam',
#  469: 'Vietnam',
#  470: 'Vietnam',
#  471: 'Vietnam',
#  472: 'Vietnam',
#  473: 'Vietnam',
#  474: 'Vietnam',
#  475: 'Vietnam',
#  476: 'Vietnam',
#  477: 'Vietnam',
#  478: 'Vietnam',
#  479: 'Vietnam',
#  480: 'Vietnam',
#  481: 'Vietnam',
#  482: 'Vietnam',
#  483: 'Vietnam',
#  484: 'Vietnam',
#  485: 'Vietnam',
#  486: 'Vietnam',
#  487: 'Vietnam',
#  488: 'Vietnam',
#  489: 'Vietnam',
#  490: 'Vietnam',
#  491: 'Vietnam',
#  492: 'Vietnam',
#  493: 'Vietnam',
#  494: 'Vietnam',
#  495: 'Vietnam',
#  496: 'Vietnam',
#  497: 'Vietnam',
#  498: 'Vietnam',
#  499: 'Vietnam',
#  500: 'Vietnam',
#  501: 'Vietnam',
#  502: 'Vietnam',
#  503: 'Vietnam',
#  504: 'Vietnam',
#  505: 'Vietnam',
#  506: 'Vietnam',
#  507: 'Vietnam',
#  508: 'Vietnam',
#  509: 'Vietnam',
#  510: 'Vietnam',
#  511: 'Vietnam',
#  512: 'Vietnam',
#  513: 'Vietnam',
#  514: 'Vietnam',
#  515: 'Vietnam',
#  516: 'Vietnam',
#  517: 'Vietnam',
#  518: 'Vietnam',
#  519: 'Vietnam',
#  520: 'Vietnam',
#  521: 'Vietnam',
#  522: 'Vietnam',
#  523: 'Vietnam',
#  524: 'Vietnam',
#  525: 'Vietnam',
#  526: 'Vietnam',
#  527: 'Vietnam',
#  528: 'Vietnam',
#  529: 'Vietnam',
#  530: 'Vietnam',
#  531: 'Vietnam',
#  532: 'Vietnam',
#  533: 'Vietnam',
#  534: 'Vietnam',
#  535: 'Vietnam',
#  536: 'Vietnam',
#  537: 'Vietnam',
#  538: 'Vietnam',
#  539: 'Vietnam',
#  540: 'Vietnam',
#  541: 'Vietnam',
#  542: 'Vietnam',
#  543: 'Vietnam',
#  544: 'Vietnam',
#  545: 'Vietnam',
#  546: 'Vietnam',
#  547: 'Vietnam',
#  548: 'Vietnam',
#  549: 'Vietnam',
#  550: 'Vietnam',
#  551: 'Vietnam',
#  552: 'Vietnam',
#  553: 'Vietnam',
#  554: 'Vietnam',
#  555: 'Vietnam',
#  556: 'Vietnam',
#  557: 'Vietnam',
#  558: 'Vietnam',
#  559: 'Vietnam',
#  560: 'Vietnam',
#  561: 'Vietnam',
#  562: 'Vietnam',
#  563: 'Vietnam',
#  564: 'Vietnam',
#  565: 'Vietnam',
#  566: 'Vietnam',
#  567: 'Vietnam',
#  568: 'Vietnam',
#  569: 'Vietnam',
#  570: 'Vietnam',
#  571: 'Vietnam',
#  572: 'Vietnam',
#  573: 'Vietnam',
#  574: 'Vietnam',
#  575: 'Vietnam',
#  576: 'Vietnam',
#  577: 'Vietnam',
#  578: 'Vietnam',
#  579: 'Vietnam',
#  580: 'Vietnam',
#  581: 'Vietnam',
#  582: 'Vietnam',
#  583: 'Vietnam',
#  584: 'Vietnam',
#  585: 'Vietnam',
#  586: 'Vietnam',
#  587: 'Vietnam',
#  588: 'Vietnam',
#  589: 'Vietnam',
#  590: 'Vietnam',
#  591: 'Vietnam',
#  592: 'Vietnam',
#  593: 'Vietnam',
#  594: 'Vietnam',
#  595: 'Vietnam',
#  596: 'Vietnam',
#  597: 'Vietnam',
#  598: 'Vietnam',
#  599: 'Vietnam',
#  600: 'Vietnam',
#  601: 'Vietnam',
#  602: 'Vietnam',
#  603: 'Vietnam',
#  604: 'Vietnam',
#  605: 'Vietnam',
#  606: 'Vietnam',
#  607: 'Vietnam',
#  608: 'Vietnam',
#  609: 'Vietnam',
#  610: 'Vietnam',
#  611: 'Vietnam',
#  612: 'Vietnam',
#  613: 'Vietnam',
#  614: 'Vietnam',
#  615: 'Vietnam',
#  616: 'Vietnam',
#  617: 'Vietnam',
#  618: 'Vietnam',
#  619: 'Vietnam',
#  620: 'Vietnam',
#  621: 'Vietnam',
#  622: 'Vietnam',
#  623: 'Vietnam',
#  624: 'Vietnam',
#  625: 'Vietnam',
#  626: 'Vietnam',
#  627: 'Vietnam',
#  628: 'Vietnam',
#  629: 'Vietnam',
#  630: 'Vietnam',
#  631: 'Vietnam',
#  632: 'Vietnam',
#  633: 'Vietnam',
#  634: 'Vietnam',
#  635: 'Vietnam',
#  636: 'Vietnam',
#  637: 'Vietnam',
#  638: 'Vietnam',
#  639: 'Vietnam',
#  640: 'Vietnam',
#  641: 'Vietnam',
#  642: 'Vietnam',
#  643: 'Vietnam',
#  644: 'Vietnam',
#  645: 'Vietnam',
#  646: 'Vietnam',
#  647: 'Vietnam',
#  648: 'Vietnam',
#  649: 'Vietnam',
#  650: 'Vietnam',
#  651: 'Vietnam',
#  652: 'Vietnam',
#  653: 'Vietnam',
#  654: 'Vietnam',
#  655: 'Vietnam',
#  656: 'Vietnam',
#  657: 'Vietnam',
#  658: 'Vietnam',
#  659: 'Vietnam',
#  660: 'Vietnam',
#  661: 'Vietnam',
#  662: 'Vietnam',
#  663: 'Vietnam',
#  664: 'Vietnam',
#  665: 'Vietnam',
#  666: 'Vietnam',
#  667: 'Vietnam',
#  668: 'Vietnam',
#  669: 'Vietnam',
#  670: 'Vietnam',
#  671: 'Vietnam',
#  672: 'Vietnam',
#  673: 'Vietnam',
#  674: 'Vietnam',
#  675: 'Vietnam',
#  676: 'Vietnam',
#  677: 'Vietnam',
#  678: 'Vietnam',
#  679: 'Vietnam',
#  680: 'Vietnam',
#  681: 'Vietnam',
#  682: 'Vietnam',
#  683: 'Vietnam',
#  684: 'Vietnam',
#  685: 'Vietnam',
#  686: 'Vietnam',
#  687: 'Vietnam',
#  688: 'Vietnam',
#  689: 'Vietnam',
#  690: 'Vietnam',
#  691: 'Vietnam',
#  692: 'Vietnam',
#  693: 'Vietnam',
#  694: 'Vietnam',
#  695: 'Vietnam',
#  696: 'Vietnam',
#  697: 'Vietnam',
#  698: 'Vietnam',
#  699: 'Vietnam',
#  700: 'Vietnam',
#  701: 'Vietnam',
#  702: 'Vietnam',
#  703: 'Vietnam',
#  704: 'Vietnam',
#  705: 'Vietnam',
#  706: 'Vietnam',
#  707: 'Vietnam',
#  708: 'Vietnam',
#  709: 'Vietnam',
#  710: 'Vietnam',
#  711: 'Vietnam',
#  712: 'Vietnam',
#  713: 'Vietnam',
#  714: 'Vietnam',
#  715: 'Vietnam',
#  716: 'Vietnam',
#  717: 'Vietnam',
#  718: 'Vietnam',
#  719: 'Vietnam',
#  720: 'Vietnam',
#  721: 'Vietnam',
#  722: 'Vietnam',
#  723: 'Vietnam',
#  724: 'Vietnam',
#  725: 'Vietnam',
#  726: 'Vietnam',
#  727: 'Vietnam',
#  728: 'Vietnam',
#  729: 'Vietnam',
#  730: 'Vietnam',
#  731: 'Vietnam',
#  732: 'Vietnam',
#  733: 'Vietnam',
#  734: 'Vietnam',
#  735: 'Vietnam',
#  736: 'Vietnam',
#  737: 'Vietnam',
#  738: 'Vietnam',
#  739: 'Vietnam',
#  740: 'Vietnam',
#  741: 'Vietnam',
#  742: 'Vietnam',
#  743: 'Vietnam',
#  744: 'Vietnam',
#  745: 'Vietnam',
#  746: 'Vietnam',
#  747: 'Vietnam',
#  748: 'Vietnam',
#  749: 'Vietnam',
#  750: 'Vietnam',
#  751: 'Vietnam',
#  752: 'Vietnam',
#  753: 'Vietnam',
#  754: 'Vietnam',
#  755: 'Vietnam',
#  756: 'Vietnam',
#  757: 'Vietnam',
#  758: 'Vietnam',
#  759: 'Vietnam',
#  760: 'Vietnam',
#  761: 'Vietnam',
#  762: 'Vietnam',
#  763: 'Vietnam',
#  764: 'Vietnam',
#  765: 'Vietnam',
#  766: 'Vietnam',
#  767: 'Vietnam',
#  768: 'Vietnam',
#  769: 'Vietnam',
#  770: 'Vietnam',
#  771: 'Vietnam',
#  772: 'Vietnam',
#  773: 'Vietnam',
#  774: 'Vietnam',
#  775: 'Vietnam',
#  776: 'Vietnam',
#  777: 'Vietnam',
#  778: 'Vietnam',
#  779: 'Vietnam',
#  780: 'Vietnam',
#  781: 'Vietnam',
#  782: 'Vietnam',
#  783: 'Vietnam',
#  784: 'Vietnam',
#  785: 'Vietnam',
#  786: 'Vietnam',
#  787: 'Vietnam',
#  788: 'Vietnam',
#  789: 'Vietnam',
#  790: 'Vietnam',
#  791: 'Vietnam',
#  792: 'Vietnam',
#  793: 'Vietnam',
#  794: 'Vietnam',
#  795: 'Vietnam',
#  796: 'Vietnam',
#  797: 'Vietnam',
#  798: 'Vietnam',
#  799: 'Vietnam',
#  800: 'Vietnam',
#  801: 'Vietnam',
#  802: 'Vietnam',
#  803: 'Vietnam',
#  804: 'Vietnam',
#  805: 'Vietnam',
#  806: 'Vietnam',
#  807: 'Vietnam',
#  808: 'Vietnam',
#  809: 'Vietnam',
#  810: 'Vietnam',
#  811: 'Vietnam',
#  812: 'Vietnam',
#  813: 'Vietnam',
#  814: 'Vietnam',
#  815: 'Vietnam',
#  816: 'Vietnam',
#  817: 'Vietnam',
#  818: 'Vietnam',
#  819: 'Vietnam',
#  820: 'Vietnam',
#  821: 'Vietnam',
#  822: 'Vietnam',
#  823: 'Vietnam',
#  824: 'Vietnam',
#  825: 'Vietnam',
#  826: 'Vietnam',
#  827: 'Vietnam',
#  828: 'Vietnam',
#  829: 'Vietnam',
#  830: 'Vietnam',
#  831: 'Vietnam',
#  832: 'Vietnam',
#  833: 'Vietnam',
#  834: 'Vietnam',
#  835: 'Vietnam',
#  836: 'Vietnam',
#  837: 'Vietnam',
#  838: 'Vietnam',
#  839: 'Vietnam',
#  840: 'Vietnam',
#  841: 'Vietnam',
#  842: 'Vietnam',
#  843: 'Vietnam',
#  844: 'Vietnam',
#  845: 'Vietnam',
#  846: 'Vietnam',
#  847: 'Vietnam',
#  848: 'Vietnam',
#  849: 'Vietnam',
#  850: 'Vietnam',
#  851: 'Vietnam',
#  852: 'Vietnam',
#  853: 'Vietnam',
#  854: 'Vietnam',
#  855: 'Vietnam',
#  856: 'Vietnam',
#  857: 'Vietnam',
#  858: 'Vietnam',
#  859: 'Vietnam',
#  860: 'Vietnam',
#  861: 'Vietnam',
#  862: 'Vietnam',
#  863: 'Vietnam',
#  864: 'Vietnam',
#  865: 'Vietnam',
#  866: 'Vietnam',
#  867: 'Vietnam',
#  868: 'Vietnam',
#  869: 'Vietnam',
#  870: 'Vietnam',
#  871: 'Vietnam',
#  872: 'Vietnam',
#  873: 'Vietnam',
#  874: 'Vietnam',
#  875: 'Vietnam',
#  876: 'Vietnam',
#  877: 'Vietnam',
#  878: 'Vietnam',
#  879: 'Vietnam',
#  880: 'Vietnam',
#  881: 'Vietnam',
#  882: 'Vietnam',
#  883: 'Vietnam',
#  884: 'Vietnam',
#  885: 'Vietnam',
#  886: 'Vietnam',
#  887: 'Vietnam',
#  888: 'Vietnam',
#  889: 'Vietnam',
#  890: 'Vietnam',
#  891: 'Vietnam',
#  892: 'Vietnam',
#  893: 'Vietnam',
#  894: 'Vietnam',
#  895: 'Vietnam',
#  896: 'Vietnam',
#  897: 'Vietnam',
#  898: 'Vietnam',
#  899: 'Vietnam',
#  900: 'Vietnam',
#  901: 'Vietnam',
#  902: 'Vietnam',
#  903: 'Vietnam',
#  904: 'Vietnam',
#  905: 'Vietnam',
#  906: 'Vietnam',
#  907: 'Vietnam',
#  908: 'Vietnam',
#  909: 'Vietnam',
#  910: 'Vietnam',
#  911: 'Vietnam',
#  912: 'Vietnam',
#  913: 'Vietnam',
#  914: 'Vietnam',
#  915: 'Vietnam',
#  916: 'Vietnam',
#  917: 'Vietnam',
#  918: 'Vietnam',
#  919: 'Vietnam',
#  920: 'Vietnam',
#  921: 'Vietnam',
#  922: 'Vietnam',
#  923: 'Vietnam',
#  924: 'Vietnam',
#  925: 'Vietnam',
#  926: 'Vietnam',
#  927: 'Vietnam',
#  928: 'Vietnam',
#  929: 'Vietnam',
#  930: 'Vietnam',
#  931: 'Vietnam',
#  932: 'Vietnam',
#  933: 'Vietnam',
#  934: 'Vietnam',
#  935: 'Vietnam',
#  936: 'Vietnam',
#  937: 'Vietnam',
#  938: 'Vietnam',
#  939: 'Vietnam',
#  940: 'Vietnam',
#  941: 'Vietnam',
#  942: 'Vietnam',
#  943: 'Vietnam',
#  944: 'Vietnam',
#  945: 'Vietnam',
#  946: 'Vietnam',
#  947: 'Vietnam',
#  948: 'Vietnam',
#  949: 'Vietnam',
#  950: 'Vietnam',
#  951: 'Vietnam',
#  952: 'Vietnam',
#  953: 'Vietnam',
#  954: 'Vietnam',
#  955: 'Vietnam',
#  956: 'Vietnam',
#  957: 'Vietnam',
#  958: 'Vietnam',
#  959: 'Vietnam',
#  960: 'Vietnam',
#  961: 'Vietnam',
#  962: 'Vietnam',
#  963: 'Vietnam',
#  964: 'Vietnam',
#  965: 'Vietnam',
#  966: 'Vietnam',
#  967: 'Vietnam',
#  968: 'Vietnam',
#  969: 'Vietnam',
#  970: 'Vietnam',
#  971: 'Vietnam',
#  972: 'Vietnam',
#  973: 'Vietnam',
#  974: 'Vietnam',
#  975: 'Vietnam',
#  976: 'Vietnam',
#  977: 'Vietnam',
#  978: 'Vietnam',
#  979: 'Vietnam',
#  980: 'Vietnam',
#  981: 'Vietnam',
#  982: 'Vietnam',
#  983: 'Vietnam',
#  984: 'Vietnam',
#  985: 'Vietnam',
#  986: 'Vietnam',
#  987: 'Vietnam',
#  988: 'Vietnam',
#  989: 'Vietnam',
#  990: 'Vietnam',
#  991: 'Vietnam',
#  992: 'Vietnam',
#  993: 'Vietnam',
#  994: 'Vietnam',
#  995: 'Vietnam',
#  996: 'Vietnam',
#  997: 'Vietnam',
#  998: 'Vietnam',
#  999: 'Vietnam',
#  ...}
